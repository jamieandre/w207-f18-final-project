# %%
# %matplotlib inline

import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import math
import random
import copy

from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

from sklearn.utils import shuffle
import lasagne
from lasagne import layers
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet
import pickle
import theano
from lasagne.layers import set_all_param_values
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-85e0a9b73a99> in <module>()
#      15
#      16 from sklearn.utils import shuffle
# ---> 17 import lasagne
#      18 from lasagne import layers
#      19 from lasagne.updates import nesterov_momentum
#
# ModuleNotFoundError: No module named 'lasagne'

# %% [markdown]
# ## Facial Key-Points detection
#
# Taken from Kaggle (https://www.kaggle.com/c/facial-keypoints-detection):
#
# > The objective of this task is to predict keypoint positions on face images. This can be used as a building block in several applications, such as:
# > 1. tracking faces in images and video
# > 2. analysing facial expressions
# > 3. detecting dysmorphic facial signs for medical diagnosis
# > 4. biometrics / face recognition
# >
# > Detecing facial keypoints is a very challenging problem.  Facial features vary greatly from one individual to another, and even for a single individual, there is a large amount of variation due to 3D pose, size, position, viewing angle, and illumination conditions. Computer vision research has come a long way in addressing these difficulties, but there remain many opportunities for improvement.
#
# In this project, we'll start with an EDA to identify important features, limitations and necessary transformations of our dataset. Then we will split the data into train, dev and test data to train models to evaluate different models.

# %% [markdown]
# ## EDA
#
# First we examine the data and types. Note that since there are a lot of columns, we've transponsed the rows here:

# %%
data = pd.read_csv('training.csv')
data.head(3).transpose()
# Out:
#                                                                            0  \
# left_eye_center_x                                                    66.0336
# left_eye_center_y                                                    39.0023
# right_eye_center_x                                                    30.227
# right_eye_center_y                                                   36.4217
# left_eye_inner_corner_x                                              59.5821
# left_eye_inner_corner_y                                              39.6474
# left_eye_outer_corner_x                                              73.1303
# left_eye_outer_corner_y                                                39.97
# right_eye_inner_corner_x                                             36.3566
# right_eye_inner_corner_y                                             37.3894
# right_eye_outer_corner_x                                             23.4529
# right_eye_outer_corner_y                                             37.3894
# left_eyebrow_inner_end_x                                             56.9533
# left_eyebrow_inner_end_y                                             29.0336
# left_eyebrow_outer_end_x                                             80.2271
# left_eyebrow_outer_end_y                                             32.2281
# right_eyebrow_inner_end_x                                            40.2276
# right_eyebrow_inner_end_y                                            29.0023
# right_eyebrow_outer_end_x                                            16.3564
# right_eyebrow_outer_end_y                                            29.6475
# nose_tip_x                                                           44.4206
# nose_tip_y                                                           57.0668
# mouth_left_corner_x                                                  61.1953
# mouth_left_corner_y                                                  79.9702
# mouth_right_corner_x                                                 28.6145
# mouth_right_corner_y                                                  77.389
# mouth_center_top_lip_x                                               43.3126
# mouth_center_top_lip_y                                               72.9355
# mouth_center_bottom_lip_x                                            43.1307
# mouth_center_bottom_lip_y                                            84.4858
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...
#
#                                                                            1  \
# left_eye_center_x                                                    64.3329
# left_eye_center_y                                                    34.9701
# right_eye_center_x                                                   29.9493
# right_eye_center_y                                                   33.4487
# left_eye_inner_corner_x                                              58.8562
# left_eye_inner_corner_y                                              35.2743
# left_eye_outer_corner_x                                              70.7227
# left_eye_outer_corner_y                                              36.1872
# right_eye_inner_corner_x                                             36.0347
# right_eye_inner_corner_y                                             34.3615
# right_eye_outer_corner_x                                             24.4725
# right_eye_outer_corner_y                                             33.1444
# left_eyebrow_inner_end_x                                             53.9874
# left_eyebrow_inner_end_y                                             28.2759
# left_eyebrow_outer_end_x                                             78.6342
# left_eyebrow_outer_end_y                                             30.4059
# right_eyebrow_inner_end_x                                            42.7289
# right_eyebrow_inner_end_y                                             26.146
# right_eyebrow_outer_end_x                                            16.8654
# right_eyebrow_outer_end_y                                            27.0589
# nose_tip_x                                                           48.2063
# nose_tip_y                                                           55.6609
# mouth_left_corner_x                                                  56.4214
# mouth_left_corner_y                                                   76.352
# mouth_right_corner_x                                                 35.1224
# mouth_right_corner_y                                                 76.0477
# mouth_center_top_lip_x                                               46.6846
# mouth_center_top_lip_y                                               70.2666
# mouth_center_bottom_lip_x                                            45.4679
# mouth_center_bottom_lip_y                                            85.4802
# Image                      219 215 204 196 204 211 212 200 180 168 178 19...
#
#                                                                            2
# left_eye_center_x                                                    65.0571
# left_eye_center_y                                                    34.9096
# right_eye_center_x                                                   30.9038
# right_eye_center_y                                                   34.9096
# left_eye_inner_corner_x                                               59.412
# left_eye_inner_corner_y                                               36.321
# left_eye_outer_corner_x                                              70.9844
# left_eye_outer_corner_y                                               36.321
# right_eye_inner_corner_x                                             37.6781
# right_eye_inner_corner_y                                              36.321
# right_eye_outer_corner_x                                             24.9764
# right_eye_outer_corner_y                                             36.6032
# left_eyebrow_inner_end_x                                             55.7425
# left_eyebrow_inner_end_y                                             27.5709
# left_eyebrow_outer_end_x                                             78.8874
# left_eyebrow_outer_end_y                                             32.6516
# right_eyebrow_inner_end_x                                            42.1939
# right_eyebrow_inner_end_y                                            28.1355
# right_eyebrow_outer_end_x                                            16.7912
# right_eyebrow_outer_end_y                                            32.0871
# nose_tip_x                                                           47.5573
# nose_tip_y                                                           53.5389
# mouth_left_corner_x                                                  60.8229
# mouth_left_corner_y                                                  73.0143
# mouth_right_corner_x                                                 33.7263
# mouth_right_corner_y                                                  72.732
# mouth_center_top_lip_x                                               47.2749
# mouth_center_top_lip_y                                               70.1918
# mouth_center_bottom_lip_x                                            47.2749
# mouth_center_bottom_lip_y                                            78.6594
# Image                      144 142 159 180 188 188 184 180 167 132 84 59 ...

# %% [markdown]
# ### Overview of data

# %%
pd.DataFrame({'type': data.dtypes})
# Out:
#                               type
# left_eye_center_x          float64
# left_eye_center_y          float64
# right_eye_center_x         float64
# right_eye_center_y         float64
# left_eye_inner_corner_x    float64
# left_eye_inner_corner_y    float64
# left_eye_outer_corner_x    float64
# left_eye_outer_corner_y    float64
# right_eye_inner_corner_x   float64
# right_eye_inner_corner_y   float64
# right_eye_outer_corner_x   float64
# right_eye_outer_corner_y   float64
# left_eyebrow_inner_end_x   float64
# left_eyebrow_inner_end_y   float64
# left_eyebrow_outer_end_x   float64
# left_eyebrow_outer_end_y   float64
# right_eyebrow_inner_end_x  float64
# right_eyebrow_inner_end_y  float64
# right_eyebrow_outer_end_x  float64
# right_eyebrow_outer_end_y  float64
# nose_tip_x                 float64
# nose_tip_y                 float64
# mouth_left_corner_x        float64
# mouth_left_corner_y        float64
# mouth_right_corner_x       float64
# mouth_right_corner_y       float64
# mouth_center_top_lip_x     float64
# mouth_center_top_lip_y     float64
# mouth_center_bottom_lip_x  float64
# mouth_center_bottom_lip_y  float64
# Image                       object

# %% [markdown]
# As it can be seen, each image has a vector of points for each facial feature. The Image itself has an `object` dtype, however, it appears to be a string when we access it. Let's convert it into a numpy array

# %%
print(type(data['Image'][0]))
# Out:
# <class 'str'>

# %%
data['Image_Matrix'] = data['Image'].apply(
    lambda x: np.array(x.split(' '), dtype=np.float)
)

data.head(3).transpose()
# Out:
#                                                                            0  \
# left_eye_center_x                                                    66.0336
# left_eye_center_y                                                    39.0023
# right_eye_center_x                                                    30.227
# right_eye_center_y                                                   36.4217
# left_eye_inner_corner_x                                              59.5821
# left_eye_inner_corner_y                                              39.6474
# left_eye_outer_corner_x                                              73.1303
# left_eye_outer_corner_y                                                39.97
# right_eye_inner_corner_x                                             36.3566
# right_eye_inner_corner_y                                             37.3894
# right_eye_outer_corner_x                                             23.4529
# right_eye_outer_corner_y                                             37.3894
# left_eyebrow_inner_end_x                                             56.9533
# left_eyebrow_inner_end_y                                             29.0336
# left_eyebrow_outer_end_x                                             80.2271
# left_eyebrow_outer_end_y                                             32.2281
# right_eyebrow_inner_end_x                                            40.2276
# right_eyebrow_inner_end_y                                            29.0023
# right_eyebrow_outer_end_x                                            16.3564
# right_eyebrow_outer_end_y                                            29.6475
# nose_tip_x                                                           44.4206
# nose_tip_y                                                           57.0668
# mouth_left_corner_x                                                  61.1953
# mouth_left_corner_y                                                  79.9702
# mouth_right_corner_x                                                 28.6145
# mouth_right_corner_y                                                  77.389
# mouth_center_top_lip_x                                               43.3126
# mouth_center_top_lip_y                                               72.9355
# mouth_center_bottom_lip_x                                            43.1307
# mouth_center_bottom_lip_y                                            84.4858
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...
# Image_Matrix               [238.0, 236.0, 237.0, 238.0, 240.0, 240.0, 239...
#
#                                                                            1  \
# left_eye_center_x                                                    64.3329
# left_eye_center_y                                                    34.9701
# right_eye_center_x                                                   29.9493
# right_eye_center_y                                                   33.4487
# left_eye_inner_corner_x                                              58.8562
# left_eye_inner_corner_y                                              35.2743
# left_eye_outer_corner_x                                              70.7227
# left_eye_outer_corner_y                                              36.1872
# right_eye_inner_corner_x                                             36.0347
# right_eye_inner_corner_y                                             34.3615
# right_eye_outer_corner_x                                             24.4725
# right_eye_outer_corner_y                                             33.1444
# left_eyebrow_inner_end_x                                             53.9874
# left_eyebrow_inner_end_y                                             28.2759
# left_eyebrow_outer_end_x                                             78.6342
# left_eyebrow_outer_end_y                                             30.4059
# right_eyebrow_inner_end_x                                            42.7289
# right_eyebrow_inner_end_y                                             26.146
# right_eyebrow_outer_end_x                                            16.8654
# right_eyebrow_outer_end_y                                            27.0589
# nose_tip_x                                                           48.2063
# nose_tip_y                                                           55.6609
# mouth_left_corner_x                                                  56.4214
# mouth_left_corner_y                                                   76.352
# mouth_right_corner_x                                                 35.1224
# mouth_right_corner_y                                                 76.0477
# mouth_center_top_lip_x                                               46.6846
# mouth_center_top_lip_y                                               70.2666
# mouth_center_bottom_lip_x                                            45.4679
# mouth_center_bottom_lip_y                                            85.4802
# Image                      219 215 204 196 204 211 212 200 180 168 178 19...
# Image_Matrix               [219.0, 215.0, 204.0, 196.0, 204.0, 211.0, 212...
#
#                                                                            2
# left_eye_center_x                                                    65.0571
# left_eye_center_y                                                    34.9096
# right_eye_center_x                                                   30.9038
# right_eye_center_y                                                   34.9096
# left_eye_inner_corner_x                                               59.412
# left_eye_inner_corner_y                                               36.321
# left_eye_outer_corner_x                                              70.9844
# left_eye_outer_corner_y                                               36.321
# right_eye_inner_corner_x                                             37.6781
# right_eye_inner_corner_y                                              36.321
# right_eye_outer_corner_x                                             24.9764
# right_eye_outer_corner_y                                             36.6032
# left_eyebrow_inner_end_x                                             55.7425
# left_eyebrow_inner_end_y                                             27.5709
# left_eyebrow_outer_end_x                                             78.8874
# left_eyebrow_outer_end_y                                             32.6516
# right_eyebrow_inner_end_x                                            42.1939
# right_eyebrow_inner_end_y                                            28.1355
# right_eyebrow_outer_end_x                                            16.7912
# right_eyebrow_outer_end_y                                            32.0871
# nose_tip_x                                                           47.5573
# nose_tip_y                                                           53.5389
# mouth_left_corner_x                                                  60.8229
# mouth_left_corner_y                                                  73.0143
# mouth_right_corner_x                                                 33.7263
# mouth_right_corner_y                                                  72.732
# mouth_center_top_lip_x                                               47.2749
# mouth_center_top_lip_y                                               70.1918
# mouth_center_bottom_lip_x                                            47.2749
# mouth_center_bottom_lip_y                                            78.6594
# Image                      144 142 159 180 188 188 184 180 167 132 84 59 ...
# Image_Matrix               [144.0, 142.0, 159.0, 180.0, 188.0, 188.0, 184...

# %% [markdown]
# Using this, we can plot some random images as examples

# %%
def plot_image_and_points(ax, image_vec, points_vec):
    ax.imshow(image_vec.reshape(96, 96), cmap='gray')
    if points_vec is not None:
        coords = points_vec.reshape((15, 2))
        ax.plot(coords[:, 0], coords[:, 1], 'rx')
        

def plot_random(dataset, nrows, ncols):
    #Plot a random array of faces
    face_ids = np.random.randint(low=0, high=len(dataset), size=(nrows*ncols))
    fig, axes = plt.subplots(figsize=(10, 10), nrows=nrows, ncols=ncols)
    for face_id, ax in zip(face_ids, axes.ravel()):
        plot_image_and_points(ax, dataset[face_id], None)
        ax.set_title("Image #{}".format(face_id))
        ax.axis('off')


plot_random(
    dataset=data['Image_Matrix'],
    nrows=5,
    ncols=5
)

# %%
def plot_random_with_points(images, key_point_arrays, nrows, ncols):
    #Plot a random array of faces with markers
    face_ids = np.random.randint(low=0, high=len(images), size=(nrows*ncols))
    
    fig, axes = plt.subplots(figsize=(10, 10), nrows=nrows, ncols=ncols)
    for face_id, ax in zip(face_ids, axes.ravel()):
        plot_image_and_points(ax, images[face_id], key_point_arrays[face_id])
        ax.set_title("Image #{}".format(face_id))
        ax.axis('off')


plot_random_with_points(
    images=data['Image_Matrix'],
    key_point_arrays=data.iloc[:, :-2].values,
    nrows=5,
    ncols=5
)

# %% [markdown]
# ### Looking deeper into images

# %% [markdown]
# It appears as though a lot of images are grey-scaled photographs of real faces. They could have different expressions, and some even look at slightly different angles to the camera. However, it's worthwhile to note that all images seem to have the key-points within the frame of the image (more on that in the next section).
#
# First, this is a good training example: centered, with all key points visible:

# %%
plot_image_and_points(plt, data['Image_Matrix'][1316], data.iloc[1316, :-2].values)

# %% [markdown]
# On the other hand, we have blurry or dark images with very few points visible

# %%
f, axes = plt.subplots(ncols=3, figsize=(10, 10))
for ax, face_id in zip(axes, [6232, 4703, 2909]):
    plot_image_and_points(ax, data['Image_Matrix'][face_id], data.iloc[face_id, :-2].values)

# %% [markdown]
# And then there are faces that are partially covered even though the visible key points are clear:

# %%
plot_image_and_points(plt, data['Image_Matrix'][1731], data.iloc[1731, :-2].values)

# %% [markdown]
# There are works of art in this data set as well. Some of these are faces from paintings, and as the fourth of the following examples show, they can be somewhat abstract or caricatural as well. Thus, we need to be robust to stylistic differences with how faces are depicted

# %%
f, axes = plt.subplots(ncols=2, nrows=2, figsize=(10, 10))
for ax, face_id in zip(axes.ravel(), [2497, 5748, 3571, 4099]):
    plot_image_and_points(ax, data['Image_Matrix'][face_id], data.iloc[face_id, :-2].values)

# %% [markdown]
# Finally, we have a bunch of baby pictures. This shows age isn't a constant either

# %%
f, axes = plt.subplots(ncols=2, figsize=(10, 10))
for ax, face_id in zip(axes, [6136, 2831]):
    plot_image_and_points(ax, data['Image_Matrix'][face_id], data.iloc[face_id, :-2].values)

# %% [markdown]
# ### Looking deeper into key points

# %% [markdown]
# As observed above, many key points are missing for a lot of images. This can also be seen in the counts in the summary here:

# %%
data.iloc[:, :-2].describe().transpose()
# Out:
#                             count       mean       std        min        25%  \
# left_eye_center_x          7039.0  66.359021  3.448233  22.763345  65.082895
# left_eye_center_y          7039.0  37.651234  3.152926   1.616512  35.900451
# right_eye_center_x         7036.0  30.306102  3.083230   0.686592  28.783339
# right_eye_center_y         7036.0  37.976943  3.033621   4.091264  36.327681
# left_eye_inner_corner_x    2271.0  59.159339  2.690354  19.064954  58.039339
# left_eye_inner_corner_y    2271.0  37.944752  2.307332  27.190098  36.626283
# left_eye_outer_corner_x    2267.0  73.330478  3.405852  27.571879  71.716503
# left_eye_outer_corner_y    2267.0  37.707008  2.881438  26.250023  36.085523
# right_eye_inner_corner_x   2268.0  36.652607  2.350268   5.751046  35.506126
# right_eye_inner_corner_y   2268.0  37.989902  2.311907  26.250023  36.766783
# right_eye_outer_corner_x   2268.0  22.384504  3.057122   3.980117  20.585808
# right_eye_outer_corner_y   2268.0  38.033495  2.910368  25.123828  36.534382
# left_eyebrow_inner_end_x   2270.0  56.068513  3.485485  17.888717  54.515587
# left_eyebrow_inner_end_y   2270.0  29.332678  3.078134  15.859361  27.617244
# left_eyebrow_outer_end_x   2225.0  79.482826  3.986224  32.206432  77.673916
# left_eyebrow_outer_end_y   2225.0  29.734861  3.773744  10.522325  27.667948
# right_eyebrow_inner_end_x  2270.0  39.322137  3.209641   6.921014  37.552286
# right_eyebrow_inner_end_y  2270.0  29.502998  3.106869  16.476000  27.790607
# right_eyebrow_outer_end_x  2236.0  15.871177  3.622533   3.826243  13.562183
# right_eyebrow_outer_end_y  2236.0  30.428166  3.865772  13.224453  28.206046
# nose_tip_x                 7049.0  48.374186  4.280038  12.944699  46.602370
# nose_tip_y                 7049.0  62.715884  5.720567  17.932414  59.292697
# mouth_left_corner_x        2269.0  63.285735  4.079063  22.923362  61.257143
# mouth_left_corner_y        2269.0  75.970714  4.579724  57.023258  72.875707
# mouth_right_corner_x       2270.0  32.900404  3.964552   2.245766  30.797646
# mouth_right_corner_y       2270.0  76.179768  4.417814  56.690208  73.256472
# mouth_center_top_lip_x     2275.0  47.975412  3.323060  12.605173  46.494571
# mouth_center_top_lip_y     2275.0  72.919443  5.222500  56.719043  69.396748
# mouth_center_bottom_lip_x  7016.0  48.569472  4.269961  12.536477  46.573703
# mouth_center_bottom_lip_y  7016.0  78.970146  5.407844  25.850503  75.549715
#
#                                  50%        75%        max
# left_eye_center_x          66.497566  68.024752  94.689280
# left_eye_center_y          37.528055  39.258449  80.502649
# right_eye_center_x         30.251378  31.768334  85.039381
# right_eye_center_y         37.813273  39.566729  81.270911
# left_eye_inner_corner_x    59.304615  60.519810  84.440991
# left_eye_inner_corner_y    37.878040  39.260348  66.562559
# left_eye_outer_corner_x    73.247824  75.015645  95.258090
# left_eye_outer_corner_y    37.639015  39.373489  64.618230
# right_eye_inner_corner_x   36.651562  37.753571  70.714966
# right_eye_inner_corner_y   37.944075  39.192917  69.808803
# right_eye_outer_corner_x   22.535954  24.237701  61.428580
# right_eye_outer_corner_y   37.867071  39.415051  70.746797
# left_eyebrow_inner_end_x   56.244975  57.946415  79.787831
# left_eyebrow_inner_end_y   29.528872  31.158830  60.875896
# left_eyebrow_outer_end_x   79.784229  81.590720  94.269957
# left_eyebrow_outer_end_y   29.773813  31.835621  60.500298
# right_eyebrow_inner_end_x  39.298848  40.917160  76.582388
# right_eyebrow_inner_end_y  29.569347  31.251664  62.083177
# right_eyebrow_outer_end_x  15.785709  17.999040  58.418216
# right_eyebrow_outer_end_y  30.320160  32.654768  66.751329
# nose_tip_x                 48.424713  50.330437  89.438592
# nose_tip_y                 63.451421  66.492686  95.935644
# mouth_left_corner_x        63.178286  65.376243  84.767123
# mouth_left_corner_y        75.778689  78.879123  94.673637
# mouth_right_corner_x       32.982305  35.101302  74.017993
# mouth_right_corner_y       76.000592  78.956357  95.510678
# mouth_center_top_lip_x     47.905490  49.296488  83.989082
# mouth_center_top_lip_y     72.605173  76.221644  94.548359
# mouth_center_bottom_lip_x  48.594978  50.677631  89.438592
# mouth_center_bottom_lip_y  78.696326  82.233993  95.808983

# %% [markdown]
# Box plots show the variance and mean of the available points. Here we can observe some patterns suggestive of correlation between some key points, and large variances among others:
# 1 - the x and y values for mouth key points have similar, though not perfectly same ranges
# 2 - y values of inner key points for the eyes are similar
# 3 - outer key points for mouth, eyebrow and eye aren't similar, but seem to have similar ranges around opposite parts of the image

# %%
plt.figure(figsize=(10, 10))
data.iloc[:, :-2].boxplot()
plt.xticks(rotation=90);

# %% [markdown]
# Let's also look at a correlation matrix among those points. Here we can observe some cells have strong correlations above 0.8. Interestingly, most of the cells with more than 0.9 correlation appear to be y values like left-eye-inner-corner-y and left-eye-center-y. Correlations between similar x values aren't as strong and mostly appear to be in the range of 0.7-0.85. This could be because most of the faces seem to have good vertical orientation - most faces are straight and looking forward. However, most faces don't have consistent horizontal orientation with many people looking sideways into the camera.

# %%
data.iloc[:, :-2].corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col0 {
#             background-color:  #023858;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col1 {
#             background-color:  #b9c6e0;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col2 {
#             background-color:  #94b6d7;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col3 {
#             background-color:  #f2ecf5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col4 {
#             background-color:  #045788;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col5 {
#             background-color:  #c5cce3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col6 {
#             background-color:  #034f7d;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col7 {
#             background-color:  #9cb9d9;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col8 {
#             background-color:  #8cb3d5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col9 {
#             background-color:  #eee9f3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col10 {
#             background-color:  #d9d8ea;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col11 {
#             background-color:  #e8e4f0;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col12 {
#             background-color:  #1077b4;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col13 {
#             background-color:  #f4edf6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col14 {
#             background-color:  #045d92;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col15 {
#             background-color:  #c5cce3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col16 {
#             background-color:  #adc1dd;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col17 {
#             background-color:  #f2ecf5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col18 {
#             background-color:  #dbdaeb;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col19 {
#             background-color:  #f1ebf4;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col20 {
#             background-color:  #62a2cb;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col21 {
#             background-color:  #bbc7e0;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col22 {
#             background-color:  #4295c3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col23 {
#             background-color:  #8cb3d5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col24 {
#             background-color:  #bcc7e1;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col25 {
#             background-color:  #93b5d6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col26 {
#             background-color:  #71a8ce;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col27 {
#             background-color:  #abbfdc;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col28 {
#             background-color:  #4295c3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row0_col29 {
#             background-color:  #83afd3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col0 {
#             background-color:  #dddbec;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col1 {
#             background-color:  #023858;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col2 {
#             background-color:  #99b8d8;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col3 {
#             background-color:  #7bacd1;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col4 {
#             background-color:  #ced0e6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col5 {
#             background-color:  #03466e;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col6 {
#             background-color:  #d1d2e6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col7 {
#             background-color:  #023f64;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col8 {
#             background-color:  #c9cee4;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col9 {
#             background-color:  #358fc0;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col10 {
#             background-color:  #a7bddb;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col11 {
#             background-color:  #a2bcda;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col12 {
#             background-color:  #bfc9e1;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col13 {
#             background-color:  #2182b9;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col14 {
#             background-color:  #b3c3de;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col15 {
#             background-color:  #046097;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col16 {
#             background-color:  #bbc7e0;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col17 {
#             background-color:  #75a9cf;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col18 {
#             background-color:  #8eb3d5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col19 {
#             background-color:  #c1cae2;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col20 {
#             background-color:  #fef6fb;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col21 {
#             background-color:  #8fb4d6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col22 {
#             background-color:  #f5eef6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col23 {
#             background-color:  #4496c3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col24 {
#             background-color:  #f8f1f8;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col25 {
#             background-color:  #8eb3d5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col26 {
#             background-color:  #f8f1f8;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col27 {
#             background-color:  #8eb3d5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col28 {
#             background-color:  #eee8f3;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row1_col29 {
#             background-color:  #a9bfdc;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col0 {
#             background-color:  #9ebad9;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col1 {
#             background-color:  #7dacd1;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col2 {
#             background-color:  #023858;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col3 {
#             background-color:  #cdd0e5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col4 {
#             background-color:  #8cb3d5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col5 {
#             background-color:  #abbfdc;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col6 {
#             background-color:  #d2d3e7;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col7 {
#             background-color:  #9cb9d9;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col8 {
#             background-color:  #045e93;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col9 {
#             background-color:  #cacee5;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col10 {
#             background-color:  #045483;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col11 {
#             background-color:  #d0d1e6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col12 {
#             background-color:  #80aed2;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col13 {
#             background-color:  #c1cae2;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col14 {
#             background-color:  #d0d1e6;
#         }    #T_46f64d6c_fd0d_11e8_9418_18d6c76121c2row2_col15 {
#             background-color:  #a2bcda;
#         }    #T_46f64d6c_fd0d_11e

# %% [markdown]
# Here we can visualize the distribution of key points. The left image contains a sample of points to show how key points vary. The right image shows the average value of facial key points alone.

# %%
f, axes = plt.subplots(ncols=2, figsize=(10, 10))


# plot a sample of points
axes[0].imshow(data['Image_Matrix'][1316].reshape(96,96), cmap='gray')
for row_num in np.random.randint(len(data), size=100):
    row = data.iloc[row_num, :-2].values
    points = row.reshape(15, 2)
    for idx, point in enumerate(points):
        axes[0].scatter(point[0], point[1], color='C' + str(idx % 10))


# plot the mean values we computed above
plot_image_and_points(axes[1], data['Image_Matrix'][1316], data.iloc[:, :-2].mean().values)

# %% [markdown]
# We can visually support some of the observations we made earlier about correlations between different points

# %% [markdown]
# ### Missing data:

# %% [markdown]
# It appears as though some rows also have some missing values for some columns

# %%
# Files appear to be organized with NaNs at the end
# plot a bar of values to position of the data
data.describe().loc['count'].plot.bar();

# %% [markdown]
# Particularly, we've noticed that the data in the lower rows tend to have missing values. Below is the first and last row of the dataset as examples:

# %%
# first and last row plotted
f, axes = plt.subplots(nrows=1, ncols=2)
plot_image_and_points(axes[0], data['Image_Matrix'][0], data.iloc[0, :-2].values)
plot_image_and_points(axes[1], data['Image_Matrix'][len(data)-1], data.iloc[len(data)-1, :-2].values)

# dataframe for reference
data.iloc[[0, -1]].transpose()
# Out:
#                                                                         0     \
# left_eye_center_x                                                    66.0336
# left_eye_center_y                                                    39.0023
# right_eye_center_x                                                    30.227
# right_eye_center_y                                                   36.4217
# left_eye_inner_corner_x                                              59.5821
# left_eye_inner_corner_y                                              39.6474
# left_eye_outer_corner_x                                              73.1303
# left_eye_outer_corner_y                                                39.97
# right_eye_inner_corner_x                                             36.3566
# right_eye_inner_corner_y                                             37.3894
# right_eye_outer_corner_x                                             23.4529
# right_eye_outer_corner_y                                             37.3894
# left_eyebrow_inner_end_x                                             56.9533
# left_eyebrow_inner_end_y                                             29.0336
# left_eyebrow_outer_end_x                                             80.2271
# left_eyebrow_outer_end_y                                             32.2281
# right_eyebrow_inner_end_x                                            40.2276
# right_eyebrow_inner_end_y                                            29.0023
# right_eyebrow_outer_end_x                                            16.3564
# right_eyebrow_outer_end_y                                            29.6475
# nose_tip_x                                                           44.4206
# nose_tip_y                                                           57.0668
# mouth_left_corner_x                                                  61.1953
# mouth_left_corner_y                                                  79.9702
# mouth_right_corner_x                                                 28.6145
# mouth_right_corner_y                                                  77.389
# mouth_center_top_lip_x                                               43.3126
# mouth_center_top_lip_y                                               72.9355
# mouth_center_bottom_lip_x                                            43.1307
# mouth_center_bottom_lip_y                                            84.4858
# Image                      238 236 237 238 240 240 239 241 241 243 240 23...
# Image_Matrix               [238.0, 236.0, 237.0, 238.0, 240.0, 240.0, 239...
#
#                                                                         7048
# left_eye_center_x                                                    66.9383
# left_eye_center_y                                                    43.4245
# right_eye_center_x                                                   31.0961
# right_eye_center_y                                                   39.5286
# left_eye_inner_corner_x                                                  NaN
# left_eye_inner_corner_y                                                  NaN
# left_eye_outer_corner_x                                                  NaN
# left_eye_outer_corner_y                                                  NaN
# right_eye_inner_corner_x                                                 NaN
# right_eye_inner_corner_y                                                 NaN
# right_eye_outer_corner_x                                                 NaN
# right_eye_outer_corner_y                                                 NaN
# left_eyebrow_inner_end_x                                                 NaN
# left_eyebrow_inner_end_y                                                 NaN
# left_eyebrow_outer_end_x                                                 NaN
# left_eyebrow_outer_end_y                                                 NaN
# right_eyebrow_inner_end_x                                                NaN
# right_eyebrow_inner_end_y                                                NaN
# right_eyebrow_outer_end_x                                                NaN
# right_eyebrow_outer_end_y                                                NaN
# nose_tip_x                                                           47.0693
# nose_tip_y                                                           73.0333
# mouth_left_corner_x                                                      NaN
# mouth_left_corner_y                                                      NaN
# mouth_right_corner_x                                                     NaN
# mouth_right_corner_y                                                     NaN
# mouth_center_top_lip_x                                                   NaN
# mouth_center_top_lip_y                                                   NaN
# mouth_center_bottom_lip_x                                            45.9005
# mouth_center_bottom_lip_y                                            82.7731
# Image                      53 62 67 76 86 91 97 105 105 106 107 108 112 1...
# Image_Matrix               [53.0, 62.0, 67.0, 76.0, 86.0, 91.0, 97.0, 105...

# %% [markdown]
# This can be more clearly seen if we plot the different columns as a line graph, where x is the position in the dataframe

# %%
plt.figure(figsize=(10, 10))
plt.plot(data[['left_eye_center_x', 'right_eyebrow_inner_end_x']])
plt.show();

# %% [markdown]
# For the sake of this project, we're only using complete examples. Alternatively, we could have tried to model fewer facial key points, the ones that all rows contain, but we think that's a less interesting problem to solve. However, we certainly cannot impute key points in missing columns since they don't have
#
# We also have more than 2000 complete complete in our dataset

# %%
data = data.dropna()
len(data)
# Out:
# 2140

# %% [markdown]
# ### Summary

# %% [markdown]
# In Summary, images have a few quirks:
# 1. Many images had centered faces with all key points visible
# 2. Many are blurry images (?CAN WE EVALUATE THIS STATISTICALLY?)
# 3. Some don't have enough key points visible in the image
# 4. Many are artworks - so we need to remove stylistic features from our analyses as well
# 5. Age is not a factor
#
# Key points are interesting in that we can

# %% [markdown]
# ## Modelling
#
# First we need to split the data into test and train. The loss function is RMSE
#
# TODO: FLESH THIS OUT
#
# We'll also use the following metrics for different approaches

# %%
_metrics = [
    metrics.mean_absolute_error,
    metrics.mean_squared_error,
    metrics.mean_squared_log_error,
    metrics.r2_score
]


global all_results
all_results = pd.DataFrame({
    key: []
    for key in ['method'] + [func.__name__ for func in _metrics]
})


def measure_all(method_name, true, pred):
    global all_results
    all_results = all_results.append({
        'method': method_name,
        **{
            func.__name__: func(true, pred)
            for func in _metrics
        }
    }, ignore_index=True)
    
    # return it for displaying purposes
    return all_results

# %% [markdown]
# ### Baseline - predicting the mean value for any image
#
# This is a simple model that only predicts the same mean value for each test X value

# %%
class MeanValueModel():
    def __init__(self):
        self.means = None
        
    def fit(self, X, Y):
        self.means = np.apply_along_axis(np.mean, 0, Y)
        
    def predict(self, X):
        return np.tile(self.means, len(X)).reshape((len(X), len(self.means)))


baseline_train, baseline_test = train_test_split(data, test_size=0.2)

mvm = MeanValueModel()
mvm.fit(baseline_train['Image_Matrix'].values, baseline_train.iloc[:, :-2].values)

predicted = mvm.predict(baseline_test['Image_Matrix'].values)
predicted
# Out:
# array([[66.20030515, 36.83979033, 29.65340837, ..., 72.54998014,
#         48.18557   , 82.67594717],
#        [66.20030515, 36.83979033, 29.65340837, ..., 72.54998014,
#         48.18557   , 82.67594717],
#        [66.20030515, 36.83979033, 29.65340837, ..., 72.54998014,
#         48.18557   , 82.67594717],
#        ...,
#        [66.20030515, 36.83979033, 29.65340837, ..., 72.54998014,
#         48.18557   , 82.67594717],
#        [66.20030515, 36.83979033, 29.65340837, ..., 72.54998014,
#         48.18557   , 82.67594717],
#        [66.20030515, 36.83979033, 29.65340837, ..., 72.54998014,
#         48.18557   , 82.67594717]])

# %%
# since this is the first measurement we're doing, we set this as the all_results thing
measure_all('baseline', baseline_test.iloc[:, :-2].values, predicted)
# Out:
#      method  mean_absolute_error  mean_squared_error  mean_squared_log_error  \
# 0  baseline             2.387728           10.859553                0.007299
#
#    r2_score
# 0 -0.003906

# %%
plot_image_and_points(
    plt,
    data['Image_Matrix'][1316],
    mvm.predict([data['Image_Matrix'][1316]])
)

# %% [markdown]
# ### K-Nearest Regression - similar images might have similar key points
#
# The intuition behind this model is that similar images would have similar key points. Thus, if we took the top k nearest images and averaged out the points, we should get a good guess of the key points on the tested image.

# %%
knr_train, _knr_temp = train_test_split(data, test_size=0.6)
knr_dev, knr_test = train_test_split(_knr_temp, test_size=0.5)

knr_train_X = [x for x in knr_train['Image_Matrix'].values]
knr_train_Y = [y for y in knr_train.iloc[:, :-2].values]
knr_dev_X = [x for x in knr_dev['Image_Matrix'].values]
knr_dev_Y = [y for y in knr_dev.iloc[:, :-2].values]

print(len(knr_train_X), len(knr_train_Y), len(knr_dev_X), len(knr_dev_Y))
# Out:
# 856 856 642 642

# %% [markdown]
# The following code was used to identify the ideal k value, and it's computationally intensive so it's commented out and the last run is placed in the next cell
#
# ```python
# print("Comparing mean square for different values of K")
#
# for k in range(1, 11):
#     knr_model = KNeighborsRegressor(n_neighbors=k)
#     knr_model.fit(knr_train_X, knr_train_Y)
#
#     predicted = knr_model.predict(knr_dev_X)
#     score = metrics.mean_squared_error(knr_dev_Y, predicted)
#
#     print("K => {}, MSE: {}".format(k, score))
# ```

# %% [raw]
# Comparing mean square for different values of K
# K => 1, MSE: 8.60216184581852
# K => 2, MSE: 6.935592735514963
# K => 3, MSE: 6.546611206608672
# K => 4, MSE: 6.490005279081465
# K => 5, MSE: 6.535412177921373
# K => 6, MSE: 6.566860152245154
# K => 7, MSE: 6.648553183527804
# K => 8, MSE: 6.68678334172749
# K => 9, MSE: 6.76342476170293
# K => 10, MSE: 6.803851422792919

# %% [markdown]
# It appears as though k=4 has the least mean squared error. In this case, let's measure again on the test set:

# %%
knr_model = KNeighborsRegressor(n_neighbors=4)
knr_model.fit(knr_train_X, knr_train_Y)
predicted = knr_model.predict([x for x in knr_test['Image_Matrix'].values])

measure_all('k-nearest regressor', knr_test.iloc[:, :-2].values, predicted)
# Out:
#                 method  mean_absolute_error  mean_squared_error  \
# 0             baseline             2.387728           10.859553
# 1  k-nearest regressor             1.739919            6.721712
#
#    mean_squared_log_error  r2_score
# 0                0.007299 -0.003906
# 1                0.004477  0.280368

# %%
plot_image_and_points(
    plt,
    data['Image_Matrix'][1316],
    knr_model.predict([data['Image_Matrix'][1316]])
)

# %% [markdown]
# ### K-Nearest Regression w/ Blurring - similar blurry images might have similar key points
#
# This model augments a k-nearest regressor model by blurring the training data. The intuition is the same as above, except we allow more approximate similarity between test images and training points.
#
# The blur function is below - it iterates through each pixel of an image and combines it with a weighted average of its neighboring 8 pixels

# %%
def apply_blur(vec, weight=(8.0/9.0)):
    
    # we need the weight of our neighbors to be less than 1
    assert weight <= 1.0
    
    img = np.reshape(vec, (96, 96))
    blurred_img = np.zeros((96, 96))
    
    # calculate the weight of the main pixel, and the weight of neighboring pixels
    # the default value of weight 8/9, gives equal weighting to all pixels
    center_weight = 1.0 - weight
    neighbor_weight = weight / 8
    
    # compute the blurred image (apologies for the inelegant code)
    # to keep things simple, we won't blur the edges. They're mostly black anyway
    for i in range(96):
        for j in range(96):
            if i == 0 or i == 95 or j == 0 or j == 95:
                pixel_value = img[i][j]
            else:
                pixel_value = center_weight * img[i][j]
                pixel_value += neighbor_weight * img[i-1][j-1]
                pixel_value += neighbor_weight * img[i-1][j]
                pixel_value += neighbor_weight * img[i-1][j+1]
                pixel_value += neighbor_weight * img[i][j-1]
                pixel_value += neighbor_weight * img[i][j+1]
                pixel_value += neighbor_weight * img[i+1][j-1]
                pixel_value += neighbor_weight * img[i+1][j]
                pixel_value += neighbor_weight * img[i+1][j+1]
            
            blurred_img[i][j] = pixel_value
    
    return np.reshape(blurred_img, 96 * 96)


f, axes = plt.subplots(ncols=3)
plot_image_and_points(axes[0], apply_blur(data['Image_Matrix'][1316], 0.0), data.iloc[1316, :-2].values)
plot_image_and_points(axes[1], apply_blur(data['Image_Matrix'][1316], 0.5), data.iloc[1316, :-2].values)
plot_image_and_points(axes[1], apply_blur(data['Image_Matrix'][1316], 0.9), data.iloc[1316, :-2].values)

# %%
from sklearn.neighbors import KNeighborsRegressor

knr_train, _knr_temp = train_test_split(data, test_size=0.6)
knr_dev, knr_test = train_test_split(_knr_temp, test_size=0.5)

knr_train_X = [x for x in knr_train['Image_Matrix'].values]
knr_train_Y = [y for y in knr_train.iloc[:, :-2].values]
knr_dev_X = [x for x in knr_dev['Image_Matrix'].values]
knr_dev_Y = [y for y in knr_dev.iloc[:, :-2].values]

print(len(knr_train_X), len(knr_train_Y), len(knr_dev_X), len(knr_dev_Y))
# Out:
# 856 856 642 642

# %% [markdown]
# The following code was used to identify the ideal k and blur weight value, and it's computationally intensive so it's commented out and the last run is placed in the next cell
#
# ```python
# print("Comparing mean square for different values of K and blur level")
#
# blurrings = {
#     b/10.0: [apply_blur(x, weight=b/10.0) for x in knr_train_X]
#     for b in range(10)
# }
#
# best_k = None
# best_blur_level = None
# least_error = float('inf')
# for k in range(1, 11):
#     for blur_level in [b/10.0 for b in range(10)]:
#         blurred_train_X = blurrings[blur_level]
#
#         knr_model = KNeighborsRegressor(n_neighbors=k)
#         knr_model.fit(blurred_train_X, knr_train_Y)
#
#         predicted = knr_model.predict(knr_dev_X)
#         mse = metrics.mean_squared_error(knr_dev_Y, predicted)
#
#         if mse < least_error:
#             best_k = k
#             best_blur_level = blur_level
#             least_error = mse
#
#         print("K => {}, weight => {}, MSE: {}".format(k, blur_level, mse))
#
# print("Best k: {}".format(best_k))
# print("Blur_level: {}".format(best_blur_level))
# print("Corresponding MSE: {}".format(least_error))
# ```

# %% [raw]
# Comparing mean square for different values of K and blur level
# K => 1, weight => 0.0, MSE: 8.512950654478717
# K => 1, weight => 0.1, MSE: 8.467433322117541
# K => 1, weight => 0.2, MSE: 8.43289274557657
# K => 1, weight => 0.3, MSE: 8.41021009625317
# K => 1, weight => 0.4, MSE: 8.460717345005127
# K => 1, weight => 0.5, MSE: 8.461730006398158
# K => 1, weight => 0.6, MSE: 8.5009480140938
# K => 1, weight => 0.7, MSE: 8.428830981130561
# K => 1, weight => 0.8, MSE: 8.44169598827338
# K => 1, weight => 0.9, MSE: 8.465451148184734
# K => 2, weight => 0.0, MSE: 7.185478255380862
# K => 2, weight => 0.1, MSE: 7.189119998808499
# K => 2, weight => 0.2, MSE: 7.184645897836714
# K => 2, weight => 0.3, MSE: 7.167668158726614
# K => 2, weight => 0.4, MSE: 7.16196426824787
# K => 2, weight => 0.5, MSE: 7.152906240475584
# K => 2, weight => 0.6, MSE: 7.139924076044012
# K => 2, weight => 0.7, MSE: 7.139835139004186
# K => 2, weight => 0.8, MSE: 7.1354127772110285
# K => 2, weight => 0.9, MSE: 7.142025874119478
# K => 3, weight => 0.0, MSE: 6.850189811124145
# K => 3, weight => 0.1, MSE: 6.768699266605571
# K => 3, weight => 0.2, MSE: 6.7429154313308
# K => 3, weight => 0.3, MSE: 6.720034702934959
# K => 3, weight => 0.4, MSE: 6.707718113238786
# K => 3, weight => 0.5, MSE: 6.729051881792426
# K => 3, weight => 0.6, MSE: 6.754644760550565
# K => 3, weight => 0.7, MSE: 6.742430008107898
# K => 3, weight => 0.8, MSE: 6.750913259482343
# K => 3, weight => 0.9, MSE: 6.745461997843248
# K => 4, weight => 0.0, MSE: 6.664442401587583
# K => 4, weight => 0.1, MSE: 6.662634563898377
# K => 4, weight => 0.2, MSE: 6.616772521159847
# K => 4, weight => 0.3, MSE: 6.6150750154602855
# K => 4, weight => 0.4, MSE: 6.605263214464583
# K => 4, weight => 0.5, MSE: 6.603104380037121
# K => 4, weight => 0.6, MSE: 6.627446742678088
# K => 4, weight => 0.7, MSE: 6.6079014889001435
# K => 4, weight => 0.8, MSE: 6.602767564743826
# K => 4, weight => 0.9, MSE: 6.5961582354354675
# K => 5, weight => 0.0, MSE: 6.628294594500616
# K => 5, weight => 0.1, MSE: 6.580514905041241
# K => 5, weight => 0.2, MSE: 6.569844303408893
# K => 5, weight => 0.3, MSE: 6.590215720986657
# K => 5, weight => 0.4, MSE: 6.585819620499061
# K => 5, weight => 0.5, MSE: 6.593173156272436
# K => 5, weight => 0.6, MSE: 6.566942128525955
# K => 5, weight => 0.7, MSE: 6.5586307373598025
# K => 5, weight => 0.8, MSE: 6.518045686132376
# K => 5, weight => 0.9, MSE: 6.519162692865896
# K => 6, weight => 0.0, MSE: 6.62036925255582
# K => 6, weight => 0.1, MSE: 6.626428071020898
# K => 6, weight => 0.2, MSE: 6.597930830797708
# K => 6, weight => 0.3, MSE: 6.561340335724895
# K => 6, weight => 0.4, MSE: 6.518821261777576
# K => 6, weight => 0.5, MSE: 6.507922117304377
# K => 6, weight => 0.6, MSE: 6.500675100457512
# K => 6, weight => 0.7, MSE: 6.488101087606785
# K => 6, weight => 0.8, MSE: 6.501434238131794
# K => 6, weight => 0.9, MSE: 6.479120303520872
# K => 7, weight => 0.0, MSE: 6.597754081695742
# K => 7, weight => 0.1, MSE: 6.571608646470731
# K => 7, weight => 0.2, MSE: 6.5459432554198225
# K => 7, weight => 0.3, MSE: 6.548907027611068
# K => 7, weight => 0.4, MSE: 6.523382892688486
# K => 7, weight => 0.5, MSE: 6.508935112230971
# K => 7, weight => 0.6, MSE: 6.4883359404334175
# K => 7, weight => 0.7, MSE: 6.485181584363525
# K => 7, weight => 0.8, MSE: 6.4853861539359645
# K => 7, weight => 0.9, MSE: 6.492924135831019
# K => 8, weight => 0.0, MSE: 6.636380687922318
# K => 8, weight => 0.1, MSE: 6.624950718847788
# K => 8, weight => 0.2, MSE: 6.603191433485746
# K => 8, weight => 0.3, MSE: 6.575663525896428
# K => 8, weight => 0.4, MSE: 6.582611590742966
# K => 8, weight => 0.5, MSE: 6.564896209166881
# K => 8, weight => 0.6, MSE: 6.5552432211100795
# K => 8, weight => 0.7, MSE: 6.555619768365436
# K => 8, weight => 0.8, MSE: 6.559606776307403
# K => 8, weight => 0.9, MSE: 6.562676181018428
# K => 9, weight => 0.0, MSE: 6.635384354742905
# K => 9, weight => 0.1, MSE: 6.650176967342179
# K => 9, weight => 0.2, MSE: 6.627139523129708
# K => 9, weight => 0.3, MSE: 6.606229462654342
# K => 9, weight => 0.4, MSE: 6.595122246692209
# K => 9, weight => 0.5, MSE: 6.592418857799171
# K => 9, weight => 0.6, MSE: 6.577287802693253
# K => 9, weight => 0.7, MSE: 6.572390394487575
# K => 9, weight => 0.8, MSE: 6.568242993867053
# K => 9, weight => 0.9, MSE: 6.5561061795698565
# K => 10, weight => 0.0, MSE: 6.6989682175712595
# K => 10, weight => 0.1, MSE: 6.66711546509763
# K => 10, weight => 0.2, MSE: 6.646655859645601
# K => 10, weight => 0.3, MSE: 6.639074047380376
# K => 10, weight => 0.4, MSE: 6.633424133532744
# K => 10, weight => 0.5, MSE: 6.614367749115141
# K => 10, weight => 0.6, MSE: 6.606550385323729
# K => 10, weight => 0.7, MSE: 6.598562245511709
# K => 10, weight => 0.8, MSE: 6.611689392685203
# K => 10, weight => 0.9, MSE: 6.616915950643787
# Best k: 6
# Blur_level: 0.9
# Corresponding MSE: 6.479120303520872

# %%
blurred_knr_train_X = [apply_blur(x, weight=0.9) for x in knr_train_X]

blurred_knr_model = KNeighborsRegressor(n_neighbors=6)
blurred_knr_model.fit(blurred_knr_train_X, knr_train_Y)
predicted = blurred_knr_model.predict([x for x in knr_test['Image_Matrix'].values])

measure_all('k-nearest regressor (with blurring)', knr_test.iloc[:, :-2].values, predicted)
# Out:
#                                 method  mean_absolute_error  \
# 0                             baseline             2.387728
# 1                  k-nearest regressor             1.739919
# 2  k-nearest regressor (with blurring)             1.712637
#
#    mean_squared_error  mean_squared_log_error  r2_score
# 0           10.859553                0.007299 -0.003906
# 1            6.721712                0.004477  0.280368
# 2            6.391169                0.004117  0.313549

# %%
plot_image_and_points(
    plt,
    data['Image_Matrix'][1316],
    blurred_knr_model.predict([data['Image_Matrix'][1316]])
)

# %% [markdown]
# ### Neural Network with Lasagne

# %%
train_data = pd.read_csv('training.csv')
train_data15_gah = train_data.dropna(axis = 0)

# Begin working with only the complete observations
# This removes some of the data, but eliminates the need for combining multiple models
# with different numbers of learned weights.

train_dataF_gah = copy.deepcopy(train_data15_gah)

#Convert the images to a manipulable array
train_dataF_gah['Image'] = train_dataF_gah['Image'].apply(lambda img:  np.fromstring(img, sep =' '))

#Create an array of the images
images_gah = np.vstack(train_dataF_gah['Image'].values)
#Scale the gray color from 0-1
images_gah = images_gah / 255.   
images_gah = images_gah.astype(np.float32)

#Create an array of the keypoints
keypoints_gah = train_data15_gah[train_data15_gah.columns[:-1]].values
#Scale the keypoints from -1, to pos 1 on the image
keypoints_gah = (keypoints_gah - 48) / 48 
keypoints_gah = keypoints_gah.astype(np.float32)

#Shuffle the training data
images_gah, keypoints_gah = shuffle(images_gah, keypoints_gah, random_state = 10)

# %% [markdown]
# Lasagne is a machine learning package built to run on Theano.  As it is still being developed some dependency
# issues still exist (many were encountered in model building).  The following models were run using the package
# versions below:
#
# theano 0.9.0
# Lasagne 0.2.dev1
# pygpu 0.6.9
# numpy 1.15.4
# scipy 0.19.1

# %%
# Using the Lasagne to create a simple neural net with 3 layers (1 hidden).
# This model uses the Lasagne defaults of variable epoch sample size, a 20% validation split, and a MSE loss function

model1_gah = NeuralNet(
layers = [('input', layers.InputLayer), ('hidden', layers.DenseLayer),('output', layers.DenseLayer)],
input_shape=(None, 9216), hidden_num_units=100, output_nonlinearity=None, output_num_units=30,
update=nesterov_momentum, update_learning_rate=0.01, update_momentum=0.9, regression=True, max_epochs=500, verbose=1)

# %%
# # Model is trained using training data set of images with all 15 keypoints
# # Training steps are commented out here for runtime issues
# # Pickle is used to save model results for reloading
# model1_gah.fit(images, keypoints)

# with open('model1_gah.pickle', 'wb') as f:
#     pickle.dump(model1_gah, f, -1)
    
with open('model1_gah.pickle', 'rb') as f:
    model1_gah = pickle.load(f)

# %%
def plotloss(model):
    train_loss = np.array([i["train_loss"] for i in model.train_history_])
    valid_loss = np.array([i["valid_loss"] for i in model.train_history_])
    plt.plot(train_loss, linewidth=3, label="Training")
    plt.plot(valid_loss, linewidth=3, label="Validation")
    plt.grid()
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("Loss (MSE)")
    plt.ylim(1e-4, 1e-2)
    plt.yscale("log")
    plt.show()
    
plotloss(model1_gah)

# %% [markdown]
# After 500 epochs the model is still (slowly) improving validation loss.  The final loss value is 0.00338 corresponding to a RMSE error of 2.79.

# %%
# Reshape the array of images to work with a 2D convolutional network
images2_gah = images_gah.reshape(-1, 1, 96, 96)

# %% [markdown]
# The next model incorporates Lasagne's convolution features to create a more complex model.  This includes 2D convolution layers, 2D pooling layers, and fully connected hidden layers.  This model architecture follows an example created by Daniel Nouri
# (http://danielnouri.org/notes/2014/12/17/using-convolutional-neural-nets-to-detect-facial-keypoints-tutorial/).  # This model uses the Lasagne defaults of variable epoch sample size, a 20% validation split, and a MSE loss function.

# %%
model2_gah = NeuralNet(
layers=[('input', layers.InputLayer),('conv1', layers.Conv2DLayer),('pool1', layers.MaxPool2DLayer),('conv2', layers.Conv2DLayer),
('pool2', layers.MaxPool2DLayer),('conv3', layers.Conv2DLayer),('pool3', layers.MaxPool2DLayer),('hidden4', layers.DenseLayer),
('hidden5', layers.DenseLayer),('output', layers.DenseLayer),],
input_shape=(None, 1, 96, 96),
conv1_num_filters=32, conv1_filter_size=(3, 3), pool1_pool_size=(2, 2),
conv2_num_filters=64, conv2_filter_size=(2, 2), pool2_pool_size=(2, 2),
conv3_num_filters=128, conv3_filter_size=(2, 2), pool3_pool_size=(2, 2),
hidden4_num_units=500, hidden5_num_units=500, output_num_units=30, output_nonlinearity=None,

update_learning_rate=0.01,update_momentum=0.9,regression=True,max_epochs=500,verbose=1)

# %%
# # Model is trained using training data set of images with all 15 keypoints
# # Training steps are commented out here for runtime issues
# # Pickle is used to save model results for reloading

# model2_gah.fit(images2_gah, keypoints_gah)

# with open('model2_gah.pickle', 'wb') as f:
#     pickle.dump(model2_gah, f, -1)
    
with open('model2_gah.pickle', 'rb') as f:
    model2_gah = pickle.load(f)

# %%
plotloss(model2_gah)

# %% [markdown]
# The convolution model improves faster than the simple model, but after 500 epochs the model has similar validation loss.  The final loss value is 0.00263 corresponding to a RMSE error of 2.46.  While providing an overall more accurate result, adding the convolution layers slowed the model considerable pushing the training time of the model to over 75 sec/ epoch.  As the validation loss is still improving there is a desire to allow the model to train longer.  The same layering is used, but the learning rate and momentum are changed to update throughout the training process. Again the training is commented out and the Pickled result is loaded.

# %%
def float32(k):
    return np.cast['float32'](k)

class AdjustVariable(object):
    def __init__(self, name, start=0.05, stop=0.001):
        self.name = name
        self.start, self.stop = start, stop
        self.ls = None

    def __call__(self, nn, train_history):
        if self.ls is None:
            self.ls = np.linspace(self.start, self.stop, nn.max_epochs)

        epoch = train_history[-1]['epoch']
        new_value = float32(self.ls[epoch - 1])
        getattr(nn, self.name).set_value(new_value)
        
model3_gah = NeuralNet(
layers=[('input', layers.InputLayer),('conv1', layers.Conv2DLayer),('pool1', layers.MaxPool2DLayer),('conv2', layers.Conv2DLayer),
('pool2', layers.MaxPool2DLayer),('conv3', layers.Conv2DLayer),('pool3', layers.MaxPool2DLayer),('hidden4', layers.DenseLayer),
('hidden5', layers.DenseLayer),('output', layers.DenseLayer),],
input_shape=(None, 1, 96, 96),
conv1_num_filters=32, conv1_filter_size=(3, 3), pool1_pool_size=(2, 2),
conv2_num_filters=64, conv2_filter_size=(2, 2), pool2_pool_size=(2, 2),
conv3_num_filters=128, conv3_filter_size=(2, 2), pool3_pool_size=(2, 2),
hidden4_num_units=500, hidden5_num_units=500, output_num_units=30, output_nonlinearity=None,

update_learning_rate=theano.shared(float32(0.05)),update_momentum=theano.shared(float32(0.9)),
regression=True,max_epochs=1000,
on_epoch_finished=[
AdjustVariable('update_learning_rate', start=0.05, stop=0.001),
AdjustVariable('update_momentum', start=0.9, stop=0.999)],verbose=1)

# %%
# # Model is trained using training data set of images with all 15 keypoints
# # Training steps are commented out here for runtime issues
# # Pickle is used to save model results for reloading

# model3_gah.fit(images2_gah, keypoints_gah)

# with open('model3_gah.pickle', 'wb') as f:
#     pickle.dump(model3_gah, f, -1)
    
with open('model3_gah.pickle', 'rb') as f:
    model3_gah = pickle.load(f)

# %%
plotloss(model3_gah)

# %% [markdown]
# The final validation loss of .00153 corresponds to a RMSE of 1.88, an improvement over the previous models, but plotting the loss over training shows some troubling trends.  As expected the with a higher learning rate, the train and validation loss decrease quickly early in the training, but the validation loss plateaus early in the training process.  The training loss continues to decrease most likely indicating overfitting and the concern that the model would not generalize well to other data.  We load the test data to examine some predictions on it.

# %%
test_data_gah = pd.read_csv('test.csv')

#Convert the images to a manipulable array
test_data_gah['Image'] = test_data_gah['Image'].apply(lambda img:  np.fromstring(img, sep =' '))

#Create an array of the images
test_images_gah = np.vstack(test_data_gah['Image'].values)
#Scale the gray color from 0-1
test_images_gah = test_images_gah / 255.   
test_images_gah = test_images_gah.astype(np.float32)

#Reshape the images to work with the 2D model
test_images2_gah = test_images_gah.reshape(-1, 1, 96, 96)

#Predict the 15 facial keypoints from the test images
pred_test_gah = model3_gah.predict(test_images2_gah)

#Change the predictions back to 96 X 96 arrays
pred_test_gah96 = pred_test_gah*48 + 48

#Create a Dataframe of the predicted data
column_names_gah = train_data.columns.tolist()
column_names_gah = column_names_gah[:-1]

test_df_gah = pd.DataFrame(data = pred_test_gah96, columns = column_names_gah)

def plot_random_gah(dataset1, dataset2, nrows, ncols):
    #Plot a random array of faces with markers
    faces_list = np.random.randint(low=0, high=(len(dataset2)-1), size=(nrows*ncols))
    keypoint_names = list(dataset1.columns)
    keypoint_loc = dataset1.loc[faces_list][keypoint_names]
    fig, axes = plt.subplots(figsize=(10, 10), nrows=nrows, ncols=ncols)
    for face, (coord, feature), ax in zip(faces_list, keypoint_loc.iterrows(), axes.ravel()):
        coords = feature.values.reshape((15,2))
        ax.imshow(dataset2[face].reshape(96,96), cmap='gray')
        ax.plot(coords[:, 0], coords[:, 1], 'rx')
        ax.axis('off')
        
plot_random_gah(test_df_gah, test_images2_gah, 4, 4)

# %% [markdown]
# Despite the potential for overfitting and using all of the high quality data points for training, the model appears to generalize fairly well to an array of the test images.  Unsurprisingly, the fits are considerably worse on images with multiple faces, of different sizes, and animated.  Another interesting result is the model's underperformance on faces turned at an angle.  This helps explain the earlier result of getting decent accuracy just using average location on each image.

# %% [markdown]
# ## MLP Perceptron
#
# #### Backward Propogation with L2 and L1 Regularization.
#
# Multi-layer perceptron utilizes activation functions such as Sigmoid and Hyperbolic tangent to activate the Perceptron Neuron. This model optimizes the squared-loss using LBFGS or stochastic gradient descent.

# %%
from sklearn.neural_network import MLPRegressor

clf = MLPRegressor(solver='lbfgs', alpha=1e-5,
                   hidden_layer_sizes=(5, 2), random_state=1)

clf_relu = MLPRegressor(hidden_layer_sizes=(100, ), activation='relu', solver='adam', 
                   alpha=0.0001, batch_size='auto', learning_rate='adaptive', learning_rate_init=0.001, 
                   power_t=0.5, max_iter=1000, shuffle=True, random_state=None, tol=0.0001, verbose=True, 
                   warm_start=False, momentum=0.9, nesterovs_momentum=True, early_stopping=False, 
                   validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

clf_sgd = MLPRegressor(hidden_layer_sizes=(100, ), activation='logistic', solver='sgd', 
                   alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
                   power_t=0.5, max_iter=200, shuffle=True, random_state=None, tol=0.0001, verbose=True, 
                   warm_start=False, momentum=0.001, nesterovs_momentum=True, early_stopping=False, 
                   validation_fraction=0.1, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

# %%
#reformatting data to massage dim constrains on dot products in self-NN class

train_data = pd.read_csv('~/Downloads/training.csv')

train_data.describe()
train_data.isnull().any().value_counts()
train_data.fillna(method = 'ffill',inplace = True)
train_data.isnull().any().value_counts()
imag = []
for i in range(0,7049):
    img = train_data['Image'][i].split(' ')
    img = ['0' if x == '' else x for x in img]
    imag.append(img)
    
image_list = np.array(imag,dtype = 'float')
X_train = image_list

training = train_data.drop('Image',axis = 1)

y_train = []
for i in range(0,7049):
    y = training.iloc[i,:]

    y_train.append(y)
y_train = np.array(y_train,dtype = 'float')

# %%
train_data['Image_Matrix'] = train_data['Image'].apply(
    lambda x: np.array(x.split(' '), dtype=np.float)
)

def plot_image_and_points(ax, image_vec, points_vec):
    ax.imshow(image_vec.reshape(96,96), cmap='gray')
    if points_vec is not None:
        coords = points_vec.reshape((15, 2))
        ax.plot(coords[:, 0], coords[:, 1], 'rx')
        

def plot_random_with_points(images, key_point_arrays, nrows, ncols):
    #Plot a random array of faces with markers
    face_ids = np.arange(9)
    
    fig, axes = plt.subplots(figsize=(10, 10), nrows=nrows, ncols=ncols)
    for face_id, ax in zip(face_ids, axes.ravel()):
        plot_image_and_points(ax, images[face_id], key_point_arrays[face_id])
        ax.set_title("Image #{}".format(face_id))
        ax.axis('off')

# %%
from sklearn import metrics
#Redoing this method to plot individually
_metrics = [
    metrics.mean_absolute_error,
    metrics.mean_squared_error,
    metrics.mean_squared_log_error,
    metrics.r2_score
]

global all_results
all_results = None

def measure_all(method_name, true, pred):
    temp_df = pd.DataFrame({
        'method': method_name,
        **{
            func.__name__: [func(true, pred)]
            for func in _metrics
        }
    })
    global all_results
    all_results = temp_df
        
    return all_results

# %%
clf_sgd.fit(X_train, y_train)
y_train_pred_sdg = clf_sgd.predict(X_train)
plot_random_with_points(
    images=train_data['Image_Matrix'],
    key_point_arrays=y_train[:10],
    nrows=3,
    ncols=3
)

plot_random_with_points(
    images=train_data['Image_Matrix'],
    key_point_arrays=y_train_pred_sdg[:10],
    nrows=3,
    ncols=3
)

measure_all('MLP_sdg', y_train, y_train_pred_sdg)
# Out:
# Iteration 1, loss = 354.80678357
# Iteration 2, loss = 9.03583866
# Iteration 3, loss = 4.61472849
# Iteration 4, loss = 4.56245301
# Iteration 5, loss = 4.56237353
# Iteration 6, loss = 4.56212231
# Iteration 7, loss = 4.56229342
# Iteration 8, loss = 4.56227439
# Iteration 9, loss = 4.56227140
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.
#    mean_absolute_error  mean_squared_error  mean_squared_log_error   method  \
# 0             1.829903             9.12244                0.005012  MLP_sdg
#
#    r2_score
# 0 -0.000182

# %%
clf.fit(X_train, y_train)
y_train_pred = clf.predict(X_train)
plot_random_with_points(
    images=train_data['Image_Matrix'],
    key_point_arrays=y_train[:10],
    nrows=3,
    ncols=3
)


plot_random_with_points(
    images=train_data['Image_Matrix'],
    key_point_arrays=y_train_pred[:10],
    nrows=3,
    ncols=3
)

measure_all('MLP_lbfgs', y_train, y_train_pred)
# Out:
#    mean_absolute_error  mean_squared_error  mean_squared_log_error     method  \
# 0              1.83173            9.120715                0.005009  MLP_lbfgs
#
#        r2_score
# 0 -3.023212e-11

# %%
clf_relu.fit(X_train, y_train)
y_train_pred_relu = clf_relu.predict(X_train)
plot_random_with_points(
    images=train_data['Image_Matrix'],
    key_point_arrays=y_train[:10],
    nrows=3,
    ncols=3
)


plot_random_with_points(
    images=train_data['Image_Matrix'],
    key_point_arrays=y_train_pred_relu[:10],
    nrows=3,
    ncols=3
)

measure_all('MLP_relu', y_train, y_train_pred_relu)
# Out:
# Iteration 1, loss = 15399.28262536
# Iteration 2, loss = 1338.18680868
# Iteration 3, loss = 1337.31814105
# Iteration 4, loss = 1336.32702456
# Iteration 5, loss = 1335.25046917
# Iteration 6, loss = 1334.10795335
# Iteration 7, loss = 1332.91268561
# Iteration 8, loss = 1331.67375263
# Iteration 9, loss = 1330.39789845
# Iteration 10, loss = 1329.09018931
# Iteration 11, loss = 1327.75492051
# Iteration 12, loss = 1326.39520819
# Iteration 13, loss = 1325.01423937
# Iteration 14, loss = 1323.61393533
# Iteration 15, loss = 1322.19623261
# Iteration 16, loss = 1320.76316758
# Iteration 17, loss = 1319.31578890
# Iteration 18, loss = 1317.85558077
# Iteration 19, loss = 1316.38372473
# Iteration 20, loss = 1314.90112078
# Iteration 21, loss = 1313.40866861
# Iteration 22, loss = 1311.90708535
# Iteration 23, loss = 1310.39707109
# Iteration 24, loss = 1308.87943842
# Iteration 25, loss = 1307.35446382
# Iteration 26, loss = 1305.82310884
# Iteration 27, loss = 1304.28552996
# Iteration 28, loss = 1302.74250630
# Iteration 29, loss = 1301.19411188
# Iteration 30, loss = 1299.64062190
# Iteration 31, loss = 1298.08262429
# Iteration 32, loss = 1296.52036528
# Iteration 33, loss = 1294.95441037
# Iteration 34, loss = 1293.38483963
# Iteration 35, loss = 1291.81196679
# Iteration 36, loss = 1290.23599393
# Iteration 37, loss = 1288.65715249
# Iteration 38, loss = 1287.07547804
# Iteration 39, loss = 1285.49131174
# Iteration 40, loss = 1283.90497495
# Iteration 41, loss = 1282.31624523
# Iteration 42, loss = 1280.72576689
# Iteration 43, loss = 1279.13350597
# Iteration 44, loss = 1277.53942868
# Iteration 45, loss = 1275.94402216
# Iteration 46, loss = 1274.34722654
# Iteration 47, loss = 1272.74912830
# Iteration 48, loss = 1271.14987615
# Iteration 49, loss = 1269.54969749
# Iteration 50, loss = 1267.94839370
# Iteration 51, loss = 1266.34640288
# Iteration 52, loss = 1264.74354285
# Iteration 53, loss = 1263.14006968
# Iteration 54, loss = 1261.53609828
# Iteration 55, loss = 1259.93149925
# Iteration 56, loss = 1258.32648882
# Iteration 57, loss = 1256.72123082
# Iteration 58, loss = 1255.11571084
# Iteration 59, loss = 1253.50995536
# Iteration 60, loss = 1251.90405270
# Iteration 61, loss = 1250.29808365
# Iteration 62, loss = 1248.69218084
# Iteration 63, loss = 1247.08631317
# Iteration 64, loss = 1245.48071450
# Iteration 65, loss = 1243.87512571
# Iteration 66, loss = 1242.26976694
# Iteration 67, loss = 1240.66459507
# Iteration 68, loss = 1239.05961133
# Iteration 69, loss = 1237.45515142
# Iteration 70, loss = 1235.85092886
# Iteration 71, loss = 1234.24721100
# Iteration 72, loss = 1232.64399560
# Iteration 73, loss = 1231.04112709
# Iteration 74, loss = 1229.43884920
# Iteration 75, loss = 1227.83706956
# Iteration 76, loss = 1226.23582900
# Iteration 77, loss = 1224.63537532
# Iteration 78, loss = 1223.03520552
# Iteration 79, loss = 1221.43570056
# Iteration 80, loss = 1219.83699121
# Iteration 81, loss = 1218.23904470
# Iteration 82, loss = 1216.64167265
# Iteration 83, loss = 1215.04522347
# Iteration 84, loss = 1213.44957494
# Iteration 85, loss = 1211.85458944
# Iteration 86, loss = 1210.26033403
# Iteration 87, loss = 1208.66685522
# Iteration 88, loss = 1207.07434845
# Iteration 89, loss = 1205.48259392
# Iteration 90, loss = 1203.89179752
# Iteration 91, loss = 1202.30178696
# Iteration 92, loss = 1200.71289275
# Iteration 93, loss = 1199.12476445
# Iteration 94, loss = 1197.53769340
# Iteration 95, loss = 1195.95133624
# Iteration 96, loss = 1194.36614265
# Iteration 97, loss = 1192.78187589
# Iteration 98, loss = 1191.19874610
# Iteration 99, loss = 1189.61662417
# Iteration 100, loss = 1188.03537595
# Iteration 101, loss = 1186.45511522
# Iteration 102, loss = 1184.87585093
# Iteration 103, loss = 1183.29760359
# Iteration 104, loss = 1181.72051817
# Iteration 105, loss = 1180.14435092
# Iteration 106, loss = 1178.56929847
# Iteration 107, loss = 1176.99523387
# Iteration 108, loss = 1175.42239990
# Iteration 109, loss = 1173.85058640
# Iteration 110, loss = 1172.27977560
# Iteration 111, loss = 1170.71006775
# Iteration 112, loss = 1169.14150324
# Iteration 113, loss = 1167.57397511
# Iteration 114, loss = 1166.00773151
# Iteration 115, loss = 1164.44247197
# Iteration 116, loss = 1162.87839960
# Iteration 117, loss = 1161.31552838
# Iteration 118, loss = 1159.75360085
# Iteration 119, loss = 1158.19291187
# Iteration 120, loss = 1156.63351476
# Iteration 121, loss = 1155.07510022
# Iteration 122, loss = 1153.51802916
# Iteration 123, loss = 1151.96214418
# Iteration 124, loss = 1150.40724470
# Iteration 125, loss = 1148.85358795
# Iteration 126, loss = 1147.30121346
# Iteration 127, loss = 1145.75000723
# Iteration 128, loss = 1144.20005115
# Iteration 129, loss = 1142.65117519
# Iteration 130, loss = 1141.10336649
# Iteration 131, loss = 1139.55683042
# Iteration 132, loss = 1138.01138868
# Iteration 133, loss = 1136.46715061
# Iteration 134, loss = 1134.92418724
# Iteration 135, loss = 1133.38250000
# Iteration 136, loss = 1131.84191229
# Iteration 137, loss = 1130.30251240
# Iteration 138, loss = 1128.76448267
# Iteration 139, loss = 1127.22754715
# Iteration 140, loss = 1125.69197999
# Iteration 141, loss = 1124.15744866
# Iteration 142, loss = 1122.62423453
# Iteration 143, loss = 1121.09205507
# Iteration 144, loss = 1119.56108219
# Iteration 145, loss = 1118.03135954
# Iteration 146, loss = 1116.50291221
# Iteration 147, loss = 1114.97559193
# Iteration 148, loss = 1113.44956842
# Iteration 149, loss = 1111.92482530
# Iteration 150, loss = 1110.40136698
# Iteration 151, loss = 1108.87910120
# Iteration 152, loss = 1107.35804623
# Iteration 153, loss = 1105.83811830
# Iteration 154, loss = 1104.31949986
# Iteration 155, loss = 1102.80217511
# Iteration 156, loss = 1101.28617039
# Iteration 157, loss = 1099.77130596
# Iteration 158, loss = 1098.25751670
# Iteration 159, loss = 1096.74520985
# Iteration 160, loss = 1095.23398642
# Iteration 161, loss = 1093.72407712
# Iteration 162, loss = 1092.21557055
# Iteration 163, loss = 1090.70820678
# Iteration 164, loss = 1089.20206572
# Iteration 165, loss = 1087.69714503
# Iteration 166, loss = 1086.19341004
# Iteration 167, loss = 1084.69104748
# Iteration 168, loss = 1083.18980883
# Iteration 169, loss = 1081.68989289
# Iteration 170, loss = 1080.19115937
# Iteration 171, loss = 1078.69345988
# Iteration 172, loss = 1077.19718912
# Iteration 173, loss = 1075.70224342
# Iteration 174, loss = 1074.20859161
# Iteration 175, loss = 1072.71616200
# Iteration 176, loss = 1071.22497167
# Iteration 177, loss = 1069.73500646
# Iteration 178, loss = 1068.24614475
# Iteration 179, loss = 1066.75874179
# Iteration 180, loss = 1065.27249005
# Iteration 181, loss = 1063.78736861
# Iteration 182, loss = 1062.30362190
# Iteration 183, loss = 1060.82108856
# Iteration 184, loss = 1059.33989088
# Iteration 185, loss = 1057.86010259
# Iteration 186, loss = 1056.38132925
# Iteration 187, loss = 1054.90381496
# Iteration 188, loss = 1053.42777736
# Iteration 189, loss = 1051.95271032
# Iteration 190, loss = 1050.47897295
# Iteration 191, loss = 1049.00636993
# Iteration 192, loss = 1047.53497920
# Iteration 193, loss = 1046.06500675
# Iteration 194, loss = 1044.59635200
# Iteration 195, loss = 1043.12879769
# Iteration 196, loss = 1041.66267502
# Iteration 197, loss = 1040.19797060
# Iteration 198, loss = 1038.73433310
# Iteration 199, loss = 1037.27181746
# Iteration 200, loss = 1035.81059271
# Iteration 201, loss = 1034.35071523
# Iteration 202, loss = 1032.89210874
# Iteration 203, loss = 1031.43487438
# Iteration 204, loss = 1029.97859552
# Iteration 205, loss = 1028.52359259
# Iteration 206, loss = 1027.06996939
# Iteration 207, loss = 1025.61741685
# Iteration 208, loss = 1024.16616530
# Iteration 209, loss = 1022.71613721
# Iteration 210, loss = 1021.26755588
# Iteration 211, loss = 1019.81995209
# Iteration 212, loss = 1018.37384242
# Iteration 213, loss = 1016.92891884
# Iteration 214, loss = 1015.48545441
# Iteration 215, loss = 1014.04304261
# Iteration 216, loss = 1012.60186009
# Iteration 217, loss = 1011.16196038
# Iteration 218, loss = 1009.72348066
# Iteration 219, loss = 1008.28617615
# Iteration 220, loss = 1006.85013341
# Iteration 221, loss = 1005.41518938
# Iteration 222, loss = 1003.98166288
# Iteration 223, loss = 1002.54927870
# Iteration 224, loss = 1001.11821304
# Iteration 225, loss = 999.68830431
# Iteration 226, loss = 998.25990951
# Iteration 227, loss = 996.83253290
# Iteration 228, loss = 995.40652488
# Iteration 229, loss = 993.98177556
# Iteration 230, loss = 992.55793486
# Iteration 231, loss = 991.13564275
# Iteration 232, loss = 989.71462224
# Iteration 233, loss = 988.29485660
# Iteration 234, loss = 986.87636330
# Iteration 235, loss = 985.45909242
# Iteration 236, loss = 984.04309400
# Iteration 237, loss = 982.62809620
# Iteration 238, loss = 981.21470114
# Iteration 239, loss = 979.80244792
# Iteration 240, loss = 978.39126119
# Iteration 241, loss = 976.98163613
# Iteration 242, loss = 975.57308492
# Iteration 243, loss = 974.16581633
# Iteration 244, loss = 972.75973979
# Iteration 245, loss = 971.35508244
# Iteration 246, loss = 969.95154167
# Iteration 247, loss = 968.54930039
# Iteration 248, loss = 967.14826872
# Iteration 249, loss = 965.74836993
# Iteration 250, loss = 964.34986950
# Iteration 251, loss = 962.95265069
# Iteration 252, loss = 961.55669012
# Iteration 253, loss = 960.16212091
# Iteration 254, loss = 958.76869972
# Iteration 255, loss = 957.37636862
# Iteration 256, loss = 955.98526952
# Iteration 257, loss = 954.59563420
# Iteration 258, loss = 953.20720956
# Iteration 259, loss = 951.82000179
# Iteration 260, loss = 950.43425187
# Iteration 261, loss = 949.04964242
# Iteration 262, loss = 947.66624240
# Iteration 263, loss = 946.28408075
# Iteration 264, loss = 944.90300024
# Iteration 265, loss = 943.52331952
# Iteration 266, loss = 942.14487010
# Iteration 267, loss = 940.76758948
# Iteration 268, loss = 939.39165864
# Iteration 269, loss = 938.01697914
# Iteration 270, loss = 936.64339597
# Iteration 271, loss = 935.27121162
# Iteration 272, loss = 933.90049921
# Iteration 273, loss = 932.53087400
# Iteration 274, loss = 931.16251042
# Iteration 275, loss = 929.79541846
# Iteration 276, loss = 928.42947979
# Iteration 277, loss = 927.06473244
# Iteration 278, loss = 925.70141869
# Iteration 279, loss = 924.33914785
# Iteration 280, loss = 922.97836776
# Iteration 281, loss = 921.61859986
# Iteration 282, loss = 920.26012570
# Iteration 283, loss = 918.90282719
# Iteration 284, loss = 917.54697148
# Iteration 285, loss = 916.19234523
# Iteration 286, loss = 914.83897185
# Iteration 287, loss = 913.48675754
# Iteration 288, loss = 912.13588264
# Iteration 289, loss = 910.78633481
# Iteration 290, loss = 909.43787976
# Iteration 291, loss = 908.09078890
# Iteration 292, loss = 906.74493578
# Iteration 293, loss = 905.40025704
# Iteration 294, loss = 904.05675064
# Iteration 295, loss = 902.71454917
# Iteration 296, loss = 901.37375709
# Iteration 297, loss = 900.03408028
# Iteration 298, loss = 898.69573943
# Iteration 299, loss = 897.35856433
# Iteration 300, loss = 896.02261124
# Iteration 301, loss = 894.68799797
# Iteration 302, loss = 893.35463277
# Iteration 303, loss = 892.02246317
# Iteration 304, loss = 890.69163626
# Iteration 305, loss = 889.36196783
# Iteration 306, loss = 888.03375584
# Iteration 307, loss = 886.70675857
# Iteration 308, loss = 885.38075054
# Iteration 309, loss = 884.05603728
# Iteration 310, loss = 882.73288892
# Iteration 311, loss = 881.41067029
# Iteration 312, loss = 880.08962985
# Iteration 313, loss = 878.76991317
# Iteration 314, loss = 877.45135040
# Iteration 315, loss = 876.13410116
# Iteration 316, loss = 874.81829997
# Iteration 317, loss = 873.50363016
# Iteration 318, loss = 872.19022223
# Iteration 319, loss = 870.87806854
# Iteration 320, loss = 869.56704010
# Iteration 321, loss = 868.25744843
# Iteration 322, loss = 866.94899683
# Iteration 323, loss = 865.64175745
# Iteration 324, loss = 864.33586198
# Iteration 325, loss = 863.03108842
# Iteration 326, loss = 861.72769797
# Iteration 327, loss = 860.42541862
# Iteration 328, loss = 859.12435378
# Iteration 329, loss = 857.82475072
# Iteration 330, loss = 856.52647319
# Iteration 331, loss = 855.22931542
# Iteration 332, loss = 853.93326680
# Iteration 333, loss = 852.63854777
# Iteration 334, loss = 851.34509079
# Iteration 335, loss = 850.05281562
# Iteration 336, loss = 848.76196891
# Iteration 337, loss = 847.47227998
# Iteration 338, loss = 846.18376566
# Iteration 339, loss = 844.89656663
# Iteration 340, loss = 843.61067128
# Iteration 341, loss = 842.32605733
# Iteration 342, loss = 841.04260279
# Iteration 343, loss = 839.76038185
# Iteration 344, loss = 838.47928603
# Iteration 345, loss = 837.19966922
# Iteration 346, loss = 835.92101075
# Iteration 347, loss = 834.64382274
# Iteration 348, loss = 833.36780158
# Iteration 349, loss = 832.09301066
# Iteration 350, loss = 830.81941796
# Iteration 351, loss = 829.54711094
# Iteration 352, loss = 828.27618486
# Iteration 353, loss = 827.00644745
# Iteration 354, loss = 825.73785317
# Iteration 355, loss = 824.47076008
# Iteration 356, loss = 823.20461278
# Iteration 357, loss = 821.93987426
# Iteration 358, loss = 820.67623682
# Iteration 359, loss = 819.41390610
# Iteration 360, loss = 818.15272051
# Iteration 361, loss = 816.89291625
# Iteration 362, loss = 815.63441096
# Iteration 363, loss = 814.37711151
# Iteration 364, loss = 813.12093263
# Iteration 365, loss = 811.86589303
# Iteration 366, loss = 810.61214501
# Iteration 367, loss = 809.35972855
# Iteration 368, loss = 808.10871335
# Iteration 369, loss = 806.85875480
# Iteration 370, loss = 805.61015946
# Iteration 371, loss = 804.36284110
# Iteration 372, loss = 803.11670533
# Iteration 373, loss = 801.87167529
# Iteration 374, loss = 800.62825376
# Iteration 375, loss = 799.38596303
# Iteration 376, loss = 798.14473384
# Iteration 377, loss = 796.90480265
# Iteration 378, loss = 795.66600800
# Iteration 379, loss = 794.42854137
# Iteration 380, loss = 793.19205622
# Iteration 381, loss = 791.95725766
# Iteration 382, loss = 790.72332544
# Iteration 383, loss = 789.49084284
# Iteration 384, loss = 788.25953790
# Iteration 385, loss = 787.02945121
# Iteration 386, loss = 785.80061102
# Iteration 387, loss = 784.57306304
# Iteration 388, loss = 783.34659442
# Iteration 389, loss = 782.12156716
# Iteration 390, loss = 780.89774470
# Iteration 391, loss = 779.67496084
# Iteration 392, loss = 778.45355609
# Iteration 393, loss = 777.23356775
# Iteration 394, loss = 776.01467707
# Iteration 395, loss = 774.79690231
# Iteration 396, loss = 773.58061508
# Iteration 397, loss = 772.36537300
# Iteration 398, loss = 771.15136145
# Iteration 399, loss = 769.93879965
# Iteration 400, loss = 768.72724939
# Iteration 401, loss = 767.51695761
# Iteration 402, loss = 766.30809560
# Iteration 403, loss = 765.10044678
# Iteration 404, loss = 763.89399367
# Iteration 405, loss = 762.68884040
# Iteration 406, loss = 761.48478098
# Iteration 407, loss = 760.28225574
# Iteration 408, loss = 759.08084006
# Iteration 409, loss = 757.88058448
# Iteration 410, loss = 756.68150660
# Iteration 411, loss = 755.48359480
# Iteration 412, loss = 754.28699986
# Iteration 413, loss = 753.09160886
# Iteration 414, loss = 751.89745531
# Iteration 415, loss = 750.70439220
# Iteration 416, loss = 749.51269117
# Iteration 417, loss = 748.32231000
# Iteration 418, loss = 747.13314355
# Iteration 419, loss = 745.94525141
# Iteration 420, loss = 744.75848277
# Iteration 421, loss = 743.57303091
# Iteration 422, loss = 742.38877306
# Iteration 423, loss = 741.20584903
# Iteration 424, loss = 740.02402679
# Iteration 425, loss = 738.84349433
# Iteration 426, loss = 737.66402014
# Iteration 427, loss = 736.48604260
# Iteration 428, loss = 735.30934337
# Iteration 429, loss = 734.13390340
# Iteration 430, loss = 732.95961805
# Iteration 431, loss = 731.78635585
# Iteration 432, loss = 730.61442622
# Iteration 433, loss = 729.44366215
# Iteration 434, loss = 728.27436751
# Iteration 435, loss = 727.10611935
# Iteration 436, loss = 725.93909877
# Iteration 437, loss = 724.77326691
# Iteration 438, loss = 723.60866011
# Iteration 439, loss = 722.44547768
# Iteration 440, loss = 721.28331735
# Iteration 441, loss = 720.12259334
# Iteration 442, loss = 718.96308856
# Iteration 443, loss = 717.80469208
# Iteration 444, loss = 716.64755791
# Iteration 445, loss = 715.49165762
# Iteration 446, loss = 714.33700894
# Iteration 447, loss = 713.18357114
# Iteration 448, loss = 712.03122014
# Iteration 449, loss = 710.88028255
# Iteration 450, loss = 709.73064228
# Iteration 451, loss = 708.58227363
# Iteration 452, loss = 707.43493003
# Iteration 453, loss = 706.28873153
# Iteration 454, loss = 705.14383553
# Iteration 455, loss = 704.00011946
# Iteration 456, loss = 702.85769232
# Iteration 457, loss = 701.71633390
# Iteration 458, loss = 700.57635820
# Iteration 459, loss = 699.43758059
# Iteration 460, loss = 698.30002695
# Iteration 461, loss = 697.16360844
# Iteration 462, loss = 696.02832038
# Iteration 463, loss = 694.89444015
# Iteration 464, loss = 693.76171771
# Iteration 465, loss = 692.63038749
# Iteration 466, loss = 691.50007141
# Iteration 467, loss = 690.37094225
# Iteration 468, loss = 689.24312005
# Iteration 469, loss = 688.11656236
# Iteration 470, loss = 686.99132489
# Iteration 471, loss = 685.86726146
# Iteration 472, loss = 684.74428673
# Iteration 473, loss = 683.62270987
# Iteration 474, loss = 682.50219223
# Iteration 475, loss = 681.38293188
# Iteration 476, loss = 680.26503122
# Iteration 477, loss = 679.14831867
# Iteration 478, loss = 678.03263477
# Iteration 479, loss = 676.91823718
# Iteration 480, loss = 675.80513218
# Iteration 481, loss = 674.69326532
# Iteration 482, loss = 673.58254905
# Iteration 483, loss = 672.47308347
# Iteration 484, loss = 671.36481848
# Iteration 485, loss = 670.25765612
# Iteration 486, loss = 669.15177779
# Iteration 487, loss = 668.04690570
# Iteration 488, loss = 666.94349463
# Iteration 489, loss = 665.84144780
# Iteration 490, loss = 664.74053493
# Iteration 491, loss = 663.64092492
# Iteration 492, loss = 662.54232457
# Iteration 493, loss = 661.44490244
# Iteration 494, loss = 660.34889474
# Iteration 495, loss = 659.25398485
# Iteration 496, loss = 658.16019407
# Iteration 497, loss = 657.06776043
# Iteration 498, loss = 655.97655555
# Iteration 499, loss = 654.88660232
# Iteration 500, loss = 653.79773795
# Iteration 501, loss = 652.71006662
# Iteration 502, loss = 651.62369122
# Iteration 503, loss = 650.53844228
# Iteration 504, loss = 649.45438496
# Iteration 505, loss = 648.37165620
# Iteration 506, loss = 647.29018807
# Iteration 507, loss = 646.20975834
# Iteration 508, loss = 645.13051332
# Iteration 509, loss = 644.05243020
# Iteration 510, loss = 642.97542869
# Iteration 511, loss = 641.89984116
# Iteration 512, loss = 640.82540079
# Iteration 513, loss = 639.75216290
# Iteration 514, loss = 638.68024372
# Iteration 515, loss = 637.60940223
# Iteration 516, loss = 636.53974086
# Iteration 517, loss = 635.47135253
# Iteration 518, loss = 634.40414582
# Iteration 519, loss = 633.33806822
# Iteration 520, loss = 632.27326969
# Iteration 521, loss = 631.20975284
# Iteration 522, loss = 630.14740903
# Iteration 523, loss = 629.08627021
# Iteration 524, loss = 628.02645925
# Iteration 525, loss = 626.96765557
# Iteration 526, loss = 625.91004745
# Iteration 527, loss = 624.85378888
# Iteration 528, loss = 623.79862387
# Iteration 529, loss = 622.74476802
# Iteration 530, loss = 621.69199111
# Iteration 531, loss = 620.64035407
# Iteration 532, loss = 619.58991279
# Iteration 533, loss = 618.54066775
# Iteration 534, loss = 617.49261462
# Iteration 535, loss = 616.44579671
# Iteration 536, loss = 615.40016472
# Iteration 537, loss = 614.35575396
# Iteration 538, loss = 613.31247995
# Iteration 539, loss = 612.27033887
# Iteration 540, loss = 611.22941807
# Iteration 541, loss = 610.18985237
# Iteration 542, loss = 609.15147942
# Iteration 543, loss = 608.11430199
# Iteration 544, loss = 607.07816495
# Iteration 545, loss = 606.04332649
# Iteration 546, loss = 605.00965233
# Iteration 547, loss = 603.97738826
# Iteration 548, loss = 602.94611966
# Iteration 549, loss = 601.91602910
# Iteration 550, loss = 600.88722675
# Iteration 551, loss = 599.85947251
# Iteration 552, loss = 598.83311795
# Iteration 553, loss = 597.80790066
# Iteration 554, loss = 596.78382070
# Iteration 555, loss = 595.76078402
# Iteration 556, loss = 594.73895763
# Iteration 557, loss = 593.71859200
# Iteration 558, loss = 592.69921698
# Iteration 559, loss = 591.68095347
# Iteration 560, loss = 590.66383645
# Iteration 561, loss = 589.64798509
# Iteration 562, loss = 588.63339708
# Iteration 563, loss = 587.62012786
# Iteration 564, loss = 586.60790546
# Iteration 565, loss = 585.59687288
# Iteration 566, loss = 584.58704627
# Iteration 567, loss = 583.57843650
# Iteration 568, loss = 582.57090145
# Iteration 569, loss = 581.56472269
# Iteration 570, loss = 580.55982088
# Iteration 571, loss = 579.55596558
# Iteration 572, loss = 578.55332082
# Iteration 573, loss = 577.55174437
# Iteration 574, loss = 576.55145587
# Iteration 575, loss = 575.55240805
# Iteration 576, loss = 574.55445191
# Iteration 577, loss = 573.55774153
# Iteration 578, loss = 572.56218610
# Iteration 579, loss = 571.56789839
# Iteration 580, loss = 570.57470779
# Iteration 581, loss = 569.58255712
# Iteration 582, loss = 568.59194661
# Iteration 583, loss = 567.60215615
# Iteration 584, loss = 566.61388126
# Iteration 585, loss = 565.62659086
# Iteration 586, loss = 564.64054953
# Iteration 587, loss = 563.65591991
# Iteration 588, loss = 562.67226589
# Iteration 589, loss = 561.68977288
# Iteration 590, loss = 560.70867701
# Iteration 591, loss = 559.72865798
# Iteration 592, loss = 558.74968459
# Iteration 593, loss = 557.77187697
# Iteration 594, loss = 556.79532932
# Iteration 595, loss = 555.81990297
# Iteration 596, loss = 554.84565487
# Iteration 597, loss = 553.87274274
# Iteration 598, loss = 552.90083732
# Iteration 599, loss = 551.93034919
# Iteration 600, loss = 550.96100592
# Iteration 601, loss = 549.99270633
# Iteration 602, loss = 549.02573306
# Iteration 603, loss = 548.05987340
# Iteration 604, loss = 547.09515118
# Iteration 605, loss = 546.13178322
# Iteration 606, loss = 545.16943311
# Iteration 607, loss = 544.20822662
# Iteration 608, loss = 543.24833914
# Iteration 609, loss = 542.28963784
# Iteration 610, loss = 541.33193597
# Iteration 611, loss = 540.37550329
# Iteration 612, loss = 539.42032111
# Iteration 613, loss = 538.46612290
# Iteration 614, loss = 537.51318988
# Iteration 615, loss = 536.56147294
# Iteration 616, loss = 535.61103945
# Iteration 617, loss = 534.66164469
# Iteration 618, loss = 533.71364881
# Iteration 619, loss = 532.76660851
# Iteration 620, loss = 531.82077837
# Iteration 621, loss = 530.87606266
# Iteration 622, loss = 529.93265014
# Iteration 623, loss = 528.99034637
# Iteration 624, loss = 528.04924907
# Iteration 625, loss = 527.10944104
# Iteration 626, loss = 526.17069680
# Iteration 627, loss = 525.23321240
# Iteration 628, loss = 524.29675070
# Iteration 629, loss = 523.36145781
# Iteration 630, loss = 522.42751436
# Iteration 631, loss = 521.49465636
# Iteration 632, loss = 520.56300015
# Iteration 633, loss = 519.63247128
# Iteration 634, loss = 518.70311519
# Iteration 635, loss = 517.77510874
# Iteration 636, loss = 516.84816054
# Iteration 637, loss = 515.92258685
# Iteration 638, loss = 514.99799521
# Iteration 639, loss = 514.07470572
# Iteration 640, loss = 513.15242785
# Iteration 641, loss = 512.23132289
# Iteration 642, loss = 511.31147914
# Iteration 643, loss = 510.39277995
# Iteration 644, loss = 509.47526092
# Iteration 645, loss = 508.55876349
# Iteration 646, loss = 507.64354176
# Iteration 647, loss = 506.72951037
# Iteration 648, loss = 505.81666422
# Iteration 649, loss = 504.90502387
# Iteration 650, loss = 503.99437435
# Iteration 651, loss = 503.08487342
# Iteration 652, loss = 502.17690854
# Iteration 653, loss = 501.26995995
# Iteration 654, loss = 500.36408097
# Iteration 655, loss = 499.45935801
# Iteration 656, loss = 498.55574523
# Iteration 657, loss = 497.65335577
# Iteration 658, loss = 496.75216110
# Iteration 659, loss = 495.85223413
# Iteration 660, loss = 494.95342342
# Iteration 661, loss = 494.05579020
# Iteration 662, loss = 493.15939639
# Iteration 663, loss = 492.26399128
# Iteration 664, loss = 491.36968005
# Iteration 665, loss = 490.47673517
# Iteration 666, loss = 489.58486161
# Iteration 667, loss = 488.69416588
# Iteration 668, loss = 487.80449590
# Iteration 669, loss = 486.91616063
# Iteration 670, loss = 486.02882536
# Iteration 671, loss = 485.14277350
# Iteration 672, loss = 484.25784138
# Iteration 673, loss = 483.37416712
# Iteration 674, loss = 482.49159350
# Iteration 675, loss = 481.61018522
# Iteration 676, loss = 480.73002944
# Iteration 677, loss = 479.85097093
# Iteration 678, loss = 478.97301704
# Iteration 679, loss = 478.09641569
# Iteration 680, loss = 477.22094421
# Iteration 681, loss = 476.34654734
# Iteration 682, loss = 475.47327075
# Iteration 683, loss = 474.60116350
# Iteration 684, loss = 473.73022865
# Iteration 685, loss = 472.86039559
# Iteration 686, loss = 471.99179014
# Iteration 687, loss = 471.12445097
# Iteration 688, loss = 470.25801619
# Iteration 689, loss = 469.39292780
# Iteration 690, loss = 468.52895606
# Iteration 691, loss = 467.66610146
# Iteration 692, loss = 466.80449225
# Iteration 693, loss = 465.94402253
# Iteration 694, loss = 465.08444414
# Iteration 695, loss = 464.22624748
# Iteration 696, loss = 463.36919900
# Iteration 697, loss = 462.51347071
# Iteration 698, loss = 461.65862421
# Iteration 699, loss = 460.80493447
# Iteration 700, loss = 459.95265520
# Iteration 701, loss = 459.10148641
# Iteration 702, loss = 458.25137582
# Iteration 703, loss = 457.40243874
# Iteration 704, loss = 456.55459587
# Iteration 705, loss = 455.70786431
# Iteration 706, loss = 454.86222912
# Iteration 707, loss = 454.01777280
# Iteration 708, loss = 453.17439759
# Iteration 709, loss = 452.33221871
# Iteration 710, loss = 451.49120853
# Iteration 711, loss = 450.65144039
# Iteration 712, loss = 449.81275328
# Iteration 713, loss = 448.97518074
# Iteration 714, loss = 448.13864900
# Iteration 715, loss = 447.30348455
# Iteration 716, loss = 446.46958078
# Iteration 717, loss = 445.63676836
# Iteration 718, loss = 444.80491239
# Iteration 719, loss = 443.97421969
# Iteration 720, loss = 443.14435328
# Iteration 721, loss = 442.31589981
# Iteration 722, loss = 441.48859592
# Iteration 723, loss = 440.66260652
# Iteration 724, loss = 439.83764056
# Iteration 725, loss = 439.01365595
# Iteration 726, loss = 438.19090689
# Iteration 727, loss = 437.36923129
# Iteration 728, loss = 436.54885288
# Iteration 729, loss = 435.72949625
# Iteration 730, loss = 434.91143631
# Iteration 731, loss = 434.09435750
# Iteration 732, loss = 433.27838923
# Iteration 733, loss = 432.46364216
# Iteration 734, loss = 431.65000731
# Iteration 735, loss = 430.83753701
# Iteration 736, loss = 430.02618373
# Iteration 737, loss = 429.21607140
# Iteration 738, loss = 428.40721225
# Iteration 739, loss = 427.59926251
# Iteration 740, loss = 426.79244795
# Iteration 741, loss = 425.98684932
# Iteration 742, loss = 425.18242482
# Iteration 743, loss = 424.37900025
# Iteration 744, loss = 423.57666813
# Iteration 745, loss = 422.77567703
# Iteration 746, loss = 421.97553469
# Iteration 747, loss = 421.17650923
# Iteration 748, loss = 420.37895251
# Iteration 749, loss = 419.58238991
# Iteration 750, loss = 418.78696912
# Iteration 751, loss = 417.99254909
# Iteration 752, loss = 417.19937765
# Iteration 753, loss = 416.40719511
# Iteration 754, loss = 415.61612876
# Iteration 755, loss = 414.82633348
# Iteration 756, loss = 414.03753314
# Iteration 757, loss = 413.24996491
# Iteration 758, loss = 412.46351599
# Iteration 759, loss = 411.67829773
# Iteration 760, loss = 410.89411289
# Iteration 761, loss = 410.11088304
# Iteration 762, loss = 409.32879784
# Iteration 763, loss = 408.54773201
# Iteration 764, loss = 407.76774546
# Iteration 765, loss = 406.98908703
# Iteration 766, loss = 406.21152908
# Iteration 767, loss = 405.43519661
# Iteration 768, loss = 404.65986314
# Iteration 769, loss = 403.88554912
# Iteration 770, loss = 403.11256468
# Iteration 771, loss = 402.34051831
# Iteration 772, loss = 401.56965792
# Iteration 773, loss = 400.79989107
# Iteration 774, loss = 400.03127217
# Iteration 775, loss = 399.26402538
# Iteration 776, loss = 398.49760840
# Iteration 777, loss = 397.73248405
# Iteration 778, loss = 396.96837240
# Iteration 779, loss = 396.20528262
# Iteration 780, loss = 395.44353812
# Iteration 781, loss = 394.68284402
# Iteration 782, loss = 393.92315076
# Iteration 783, loss = 393.16475357
# Iteration 784, loss = 392.40737430
# Iteration 785, loss = 391.65107181
# Iteration 786, loss = 390.89583117
# Iteration 787, loss = 390.14165481
# Iteration 788, loss = 389.38864496
# Iteration 789, loss = 388.63671087
# Iteration 790, loss = 387.88594215
# Iteration 791, loss = 387.13639362
# Iteration 792, loss = 386.38784240
# Iteration 793, loss = 385.64034588
# Iteration 794, loss = 384.89409802
# Iteration 795, loss = 384.14902416
# Iteration 796, loss = 383.40493618
# Iteration 797, loss = 382.66200404
# Iteration 798, loss = 381.92004790
# Iteration 799, loss = 381.17925283
# Iteration 800, loss = 380.43931822
# Iteration 801, loss = 379.70066327
# Iteration 802, loss = 378.96313051
# Iteration 803, loss = 378.22673520
# Iteration 804, loss = 377.49137871
# Iteration 805, loss = 376.75717965
# Iteration 806, loss = 376.02422326
# Iteration 807, loss = 375.29230023
# Iteration 808, loss = 374.56150811
# Iteration 809, loss = 373.83155605
# Iteration 810, loss = 373.10300151
# Iteration 811, loss = 372.37557055
# Iteration 812, loss = 371.64931012
# Iteration 813, loss = 370.92412472
# Iteration 814, loss = 370.19988008
# Iteration 815, loss = 369.47694061
# Iteration 816, loss = 368.75492169
# Iteration 817, loss = 368.03394886
# Iteration 818, loss = 367.31412203
# Iteration 819, loss = 366.59533158
# Iteration 820, loss = 365.87778375
# Iteration 821, loss = 365.16116311
# Iteration 822, loss = 364.44575036
# Iteration 823, loss = 363.73135878
# Iteration 824, loss = 363.01822230
# Iteration 825, loss = 362.30624626
# Iteration 826, loss = 361.59522681
# Iteration 827, loss = 360.88526718
# Iteration 828, loss = 360.17640951
# Iteration 829, loss = 359.46874968
# Iteration 830, loss = 358.76208968
# Iteration 831, loss = 358.05662033
# Iteration 832, loss = 357.35203776
# Iteration 833, loss = 356.64856459
# Iteration 834, loss = 355.94614856
# Iteration 835, loss = 355.24492462
# Iteration 836, loss = 354.54487349
# Iteration 837, loss = 353.84571903
# Iteration 838, loss = 353.14774002
# Iteration 839, loss = 352.45097202
# Iteration 840, loss = 351.75510208
# Iteration 841, loss = 351.06030380
# Iteration 842, loss = 350.36661863
# Iteration 843, loss = 349.67417482
# Iteration 844, loss = 348.98256922
# Iteration 845, loss = 348.29221983
# Iteration 846, loss = 347.60310315
# Iteration 847, loss = 346.91483975
# Iteration 848, loss = 346.22770485
# Iteration 849, loss = 345.54166993
# Iteration 850, loss = 344.85668667
# Iteration 851, loss = 344.17274454
# Iteration 852, loss = 343.48994544
# Iteration 853, loss = 342.80814269
# Iteration 854, loss = 342.12734280
# Iteration 855, loss = 341.44776462
# Iteration 856, loss = 340.76926825
# Iteration 857, loss = 340.09176772
# Iteration 858, loss = 339.41538379
# Iteration 859, loss = 338.74017413
# Iteration 860, loss = 338.06590666
# Iteration 861, loss = 337.39274377
# Iteration 862, loss = 336.72078892
# Iteration 863, loss = 336.04975466
# Iteration 864, loss = 335.37976352
# Iteration 865, loss = 334.71092411
# Iteration 866, loss = 334.04313994
# Iteration 867, loss = 333.37640561
# Iteration 868, loss = 332.71070220
# Iteration 869, loss = 332.04620077
# Iteration 870, loss = 331.38252301
# Iteration 871, loss = 330.72019220
# Iteration 872, loss = 330.05882908
# Iteration 873, loss = 329.39845145
# Iteration 874, loss = 328.73914319
# Iteration 875, loss = 328.08086089
# Iteration 876, loss = 327.42358638
# Iteration 877, loss = 326.76748938
# Iteration 878, loss = 326.11233720
# Iteration 879, loss = 325.45838922
# Iteration 880, loss = 324.80531769
# Iteration 881, loss = 324.15350402
# Iteration 882, loss = 323.50254964
# Iteration 883, loss = 322.85269651
# Iteration 884, loss = 322.20398810
# Iteration 885, loss = 321.55619238
# Iteration 886, loss = 320.90949468
# Iteration 887, loss = 320.26369702
# Iteration 888, loss = 319.61911842
# Iteration 889, loss = 318.97555163
# Iteration 890, loss = 318.33301504
# Iteration 891, loss = 317.69165002
# Iteration 892, loss = 317.05142871
# Iteration 893, loss = 316.41191586
# Iteration 894, loss = 315.77335708
# Iteration 895, loss = 315.13608479
# Iteration 896, loss = 314.49978055
# Iteration 897, loss = 313.86440801
# Iteration 898, loss = 313.23019163
# Iteration 899, loss = 312.59704567
# Iteration 900, loss = 311.96485012
# Iteration 901, loss = 311.33372563
# Iteration 902, loss = 310.70365453
# Iteration 903, loss = 310.07446675
# Iteration 904, loss = 309.44635121
# Iteration 905, loss = 308.81925082
# Iteration 906, loss = 308.19315868
# Iteration 907, loss = 307.56833994
# Iteration 908, loss = 306.94441529
# Iteration 909, loss = 306.32148912
# Iteration 910, loss = 305.69947959
# Iteration 911, loss = 305.07850726
# Iteration 912, loss = 304.45859081
# Iteration 913, loss = 303.83984896
# Iteration 914, loss = 303.22207378
# Iteration 915, loss = 302.60525482
# Iteration 916, loss = 301.98963312
# Iteration 917, loss = 301.37487597
# Iteration 918, loss = 300.76105742
# Iteration 919, loss = 300.14827959
# Iteration 920, loss = 299.53638214
# Iteration 921, loss = 298.92568083
# Iteration 922, loss = 298.31593931
# Iteration 923, loss = 297.70710395
# Iteration 924, loss = 297.09937342
# Iteration 925, loss = 296.49262309
# Iteration 926, loss = 295.88704261
# Iteration 927, loss = 295.28231299
# Iteration 928, loss = 294.67843952
# Iteration 929, loss = 294.07564545
# Iteration 930, loss = 293.47390341
# Iteration 931, loss = 292.87320029
# Iteration 932, loss = 292.27337632
# Iteration 933, loss = 291.67458025
# Iteration 934, loss = 291.07660803
# Iteration 935, loss = 290.47973801
# Iteration 936, loss = 289.88394265
# Iteration 937, loss = 289.28901544
# Iteration 938, loss = 288.69518415
# Iteration 939, loss = 288.10229671
# Iteration 940, loss = 287.51034547
# Iteration 941, loss = 352.04030473
# Iteration 942, loss = 286.39862982
# Iteration 943, loss = 285.81463233
# Iteration 944, loss = 285.23092978
# Iteration 945, loss = 284.64793285
# Iteration 946, loss = 284.06565340
# Iteration 947, loss = 283.48408379
# Iteration 948, loss = 282.90355276
# Iteration 949, loss = 282.32359818
# Iteration 950, loss = 281.74455250
# Iteration 951, loss = 281.16633073
# Iteration 952, loss = 280.58893173
# Iteration 953, loss = 280.01227262
# Iteration 954, loss = 279.43639921
# Iteration 955, loss = 278.86147431
# Iteration 956, loss = 278.28728784
# Iteration 957, loss = 277.71401356
# Iteration 958, loss = 277.14162987
# Iteration 959, loss = 276.57000430
# Iteration 960, loss = 275.99905997
# Iteration 961, loss = 275.42915395
# Iteration 962, loss = 274.86006490
# Iteration 963, loss = 274.29172476
# Iteration 964, loss = 273.72420275
# Iteration 965, loss = 273.15768549
# Iteration 966, loss = 272.59185981
# Iteration 967, loss = 272.02700828
# Iteration 968, loss = 271.46291921
# Iteration 969, loss = 270.89977145
# Iteration 970, loss = 270.33752896
# Iteration 971, loss = 269.77609463
# Iteration 972, loss = 269.21548562
# Iteration 973, loss = 268.65583378
# Iteration 974, loss = 268.09690869
# Iteration 975, loss = 267.53893570
# Iteration 976, loss = 266.98177719
# Iteration 977, loss = 266.42570983
# Iteration 978, loss = 265.87034349
# Iteration 979, loss = 265.31593370
# Iteration 980, loss = 264.76228678
# Iteration 981, loss = 264.20964904
# Iteration 982, loss = 263.65770007
# Iteration 983, loss = 263.10667631
# Iteration 984, loss = 262.55648474
# Iteration 985, loss = 262.00723730
# Iteration 986, loss = 261.45877404
# Iteration 987, loss = 260.91123262
# Iteration 988, loss = 260.36468273
# Iteration 989, loss = 259.81891728
# Iteration 990, loss = 259.27394996
# Iteration 991, loss = 258.73010784
# Iteration 992, loss = 258.18720541
# Iteration 993, loss = 257.64508064
# Iteration 994, loss = 257.10375473
# Iteration 995, loss = 256.56331368
# Iteration 996, loss = 256.02381335
# Iteration 997, loss = 255.48513330
# Iteration 998, loss = 254.94738832
# Iteration 999, loss = 254.41059995
# Iteration 1000, loss = 253.87465041
# /anaconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
#    mean_absolute_error  mean_squared_error  mean_squared_log_error    method  \
# 0            15.932086          507.187537                0.189598  MLP_relu
#
#     r2_score
# 0 -64.794444

# %% [markdown]
# ### Discussion
#
# Multilayer perceptron models chosen, using Relu (the rectified linear unit function, returns f(x) = max(0, x)) and Logistic activation functions performed relatively poorly on the image training set.
#
# This is expected behavior as the problem at hand contains data that is not perfectly linearly seperable. That is there doesn't exist some hyperplane in R2 that seperates all the features. This also creates significant issues for the Relu activation solver as this limits convergence of the weights. As these weights do not converge to reasonable tolerance, the algorithm finds it difficult to classify each point correctly.
#
# The limitations of perceptron become apparent ont his dataset. The decision boundaries being only linear limits classification margins. To massage some of these issues, we need to incoporate feature mapping, PCA and feature combinations to reduce the dimensionality of the images and relax decision boundaries.
